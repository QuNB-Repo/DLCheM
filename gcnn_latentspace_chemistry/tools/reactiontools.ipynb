# %% [markdown]
# Generate colors gradient for the timesteps code

# %%
import pandas as pd

def generate_color_gradient(start_color, end_color, num_repetitions):
    colors = []
    color_range = end_color - start_color + 1

    for _ in range(num_repetitions):
        for i in range(color_range):
            current_color = (start_color + 10*i) % 2000
            colors.append(current_color)

    return colors

start_color = 0  # Start color (0-199)
end_color = 199  # End color (0-199)
num_repetitions = 33   # Number of repetitions

colors = generate_color_gradient(start_color, end_color, num_repetitions)

df = pd.DataFrame({'Color': colors})
df.to_csv('../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/color_gradient.csv', index=False)

# %% [markdown]
# Code that calculate difference of embeddings between consecutive timesteps

# %%
import numpy as np

number_timesteps = 200
number_molecules = 33
data_filepath = '../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolate.csv'

data = np.genfromtxt(data_filepath,delimiter=',',encoding='utf-8-sig')

differences = np.zeros((1,128))
for each_timestep in range(number_molecules*number_timesteps):
    if each_timestep % number_timesteps == 0:
        differences = np.vstack((differences,np.zeros((1,128))))
    else:
        difference = data[each_timestep,:128] - data[each_timestep-1,:128]
        differences = np.vstack((differences,difference))

differences = np.delete(differences,0,0)

save_filepath = data_filepath.replace('.csv','diff.csv')
np.savetxt(save_filepath,differences,delimiter=',')

# %% [markdown]
# Converts timesteps changes in csv sheet for each molecule
#
# Into a matrix for all molecules (Each molecule a column
# of timestep changes in the new matrix)...
#
# A matrix will be built for each embedding parameter that each molecule has

# %%
import csv
import numpy as np
from numpy import genfromtxt, savetxt



def convert_column_to_matrix(column):
    num_rows = int(len(column)/ 200)
    num_cols = 200

    matrix = np.array(column).reshape(num_rows, num_cols).T
    
    return matrix

def save_matrix_to_csv(matrix, output_file):
    with open(output_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(matrix)

def convert_matrix_to_columns(matrix):
    
    num_columns = matrix.shape[1]

    for col_index in range(num_columns):
        column = matrix[:, col_index]
        result_matrix = convert_column_to_matrix(column)
        
        num_rows = result_matrix.shape[0]
        
        # concatenate columns for row counting, average, standard deviation, upper bound, and lower bound
        row_count = np.arange(1, num_rows + 1).reshape(num_rows, 1)
        average = np.mean(result_matrix, axis=1).reshape(num_rows, 1)
        std_dev = np.std(result_matrix, axis=1).reshape(num_rows, 1)
        upper_bound = average + std_dev
        lower_bound = average - std_dev
        
        result_matrix = np.concatenate((row_count, result_matrix, average, std_dev, upper_bound, lower_bound), axis=1)
        
        output_file = data_filepath.replace('.csv','') +  f'column_{col_index + 1}_result.csv'  # File name for each column's result
        save_matrix_to_csv(result_matrix, output_file)
        print(f"Saved result for column {col_index + 1} to {output_file}")


# Usage example
data_filepath = '../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediff.csv'
input_matrix = genfromtxt(data_filepath,delimiter=',',encoding='utf-8-sig')


convert_matrix_to_columns(input_matrix)
# Out:
# Saved result for column 1 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_1_result.csv
# Saved result for column 2 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_2_result.csv
# Saved result for column 3 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_3_result.csv
# Saved result for column 4 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_4_result.csv
# Saved result for column 5 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_5_result.csv
# Saved result for column 6 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_6_result.csv
# Saved result for column 7 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_7_result.csv
# Saved result for column 8 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_8_result.csv
# Saved result for column 9 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_9_result.csv
# Saved result for column 10 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_10_result.csv
# Saved result for column 11 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_11_result.csv
# Saved result for column 12 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_12_result.csv
# Saved result for column 13 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_13_result.csv
# Saved result for column 14 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_14_result.csv
# Saved result for column 15 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_15_result.csv
# Saved result for column 16 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_16_result.csv
# Saved result for column 17 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_17_result.csv
# Saved result for column 18 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_18_result.csv
# Saved result for column 19 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_19_result.csv
# Saved result for column 20 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_20_result.csv
# Saved result for column 21 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_21_result.csv
# Saved result for column 22 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_22_result.csv
# Saved result for column 23 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_23_result.csv
# Saved result for column 24 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_24_result.csv
# Saved result for column 25 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_25_result.csv
# Saved result for column 26 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_26_result.csv
# Saved result for column 27 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_27_result.csv
# Saved result for column 28 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_28_result.csv
# Saved result for column 29 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_29_result.csv
# Saved result for column 30 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_30_result.csv
# Saved result for column 31 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_31_result.csv
# Saved result for column 32 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_32_result.csv
# Saved result for column 33 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_33_result.csv
# Saved result for column 34 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_34_result.csv
# Saved result for column 35 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_35_result.csv
# Saved result for column 36 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_36_result.csv
# Saved result for column 37 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_37_result.csv
# Saved result for column 38 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_38_result.csv
# Saved result for column 39 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_39_result.csv
# Saved result for column 40 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_40_result.csv
# Saved result for column 41 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_41_result.csv
# Saved result for column 42 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_42_result.csv
# Saved result for column 43 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_43_result.csv
# Saved result for column 44 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_44_result.csv
# Saved result for column 45 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_45_result.csv
# Saved result for column 46 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_46_result.csv
# Saved result for column 47 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_47_result.csv
# Saved result for column 48 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_48_result.csv
# Saved result for column 49 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_49_result.csv
# Saved result for column 50 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_50_result.csv
# Saved result for column 51 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_51_result.csv
# Saved result for column 52 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_52_result.csv
# Saved result for column 53 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_53_result.csv
# Saved result for column 54 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_54_result.csv
# Saved result for column 55 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_55_result.csv
# Saved result for column 56 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_56_result.csv
# Saved result for column 57 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_57_result.csv
# Saved result for column 58 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_58_result.csv
# Saved result for column 59 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_59_result.csv
# Saved result for column 60 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_60_result.csv
# Saved result for column 61 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_61_result.csv
# Saved result for column 62 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_62_result.csv
# Saved result for column 63 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_63_result.csv
# Saved result for column 64 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_64_result.csv
# Saved result for column 65 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_65_result.csv
# Saved result for column 66 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_66_result.csv
# Saved result for column 67 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_67_result.csv
# Saved result for column 68 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_68_result.csv
# Saved result for column 69 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_69_result.csv
# Saved result for column 70 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_70_result.csv
# Saved result for column 71 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_71_result.csv
# Saved result for column 72 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_72_result.csv
# Saved result for column 73 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_73_result.csv
# Saved result for column 74 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_74_result.csv
# Saved result for column 75 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_75_result.csv
# Saved result for column 76 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_76_result.csv
# Saved result for column 77 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_77_result.csv
# Saved result for column 78 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_78_result.csv
# Saved result for column 79 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_79_result.csv
# Saved result for column 80 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_80_result.csv
# Saved result for column 81 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_81_result.csv
# Saved result for column 82 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_82_result.csv
# Saved result for column 83 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_83_result.csv
# Saved result for column 84 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_84_result.csv
# Saved result for column 85 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_85_result.csv
# Saved result for column 86 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_86_result.csv
# Saved result for column 87 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_87_result.csv
# Saved result for column 88 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_88_result.csv
# Saved result for column 89 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_89_result.csv
# Saved result for column 90 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_90_result.csv
# Saved result for column 91 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_91_result.csv
# Saved result for column 92 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_92_result.csv
# Saved result for column 93 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_93_result.csv
# Saved result for column 94 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_94_result.csv
# Saved result for column 95 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_95_result.csv
# Saved result for column 96 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_96_result.csv
# Saved result for column 97 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_97_result.csv
# Saved result for column 98 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_98_result.csv
# Saved result for column 99 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_99_result.csv
# Saved result for column 100 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_100_result.csv
# Saved result for column 101 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_101_result.csv
# Saved result for column 102 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_102_result.csv
# Saved result for column 103 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_103_result.csv
# Saved result for column 104 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_104_result.csv
# Saved result for column 105 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_105_result.csv
# Saved result for column 106 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_106_result.csv
# Saved result for column 107 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_107_result.csv
# Saved result for column 108 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_108_result.csv
# Saved result for column 109 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_109_result.csv
# Saved result for column 110 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_110_result.csv
# Saved result for column 111 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_111_result.csv
# Saved result for column 112 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_112_result.csv
# Saved result for column 113 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_113_result.csv
# Saved result for column 114 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_114_result.csv
# Saved result for column 115 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_115_result.csv
# Saved result for column 116 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_116_result.csv
# Saved result for column 117 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_117_result.csv
# Saved result for column 118 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_118_result.csv
# Saved result for column 119 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_119_result.csv
# Saved result for column 120 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_120_result.csv
# Saved result for column 121 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_121_result.csv
# Saved result for column 122 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_122_result.csv
# Saved result for column 123 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_123_result.csv
# Saved result for column 124 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_124_result.csv
# Saved result for column 125 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_125_result.csv
# Saved result for column 126 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_126_result.csv
# Saved result for column 127 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_127_result.csv
# Saved result for column 128 to ../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/overtimesteps/Oembsrxnpcaisolatediffcolumn_128_result.csv

# %% [markdown]
# Tracking the FG path of the reaction over the timesteps

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('../data/fgtransform/model1/oxidation/1alcsoxpert3/rxns/timestep200-scale0.005/1000scan/rxn/predicted_classesqm9.csv')

# Specify the column name you want to analyze
column_name = 'rxn'

# Create empty lists to store the unique elements and their counts
unique_elements = []
element_counts = []

# Iterate over every 200 datapoints
for i in range(0, len(df[column_name]), 200):
    # Get the 200 datapoints in the current range
    datapoints = df[column_name][i:i+200]

    # Find unique elements and their counts
    unique = datapoints.unique()
    counts = datapoints.value_counts()

    # Append unique elements and counts to respective lists
    unique_elements.append(unique)
    element_counts.append(counts)

# Print the ordered list of unique elements and their counts
for i, unique in enumerate(unique_elements):
    print(f"Data Range {i+1}:")
    for element in unique:
        count = element_counts[i].get(element, 0)
        print(f"Element: {element}, Count: {count}")
    print()
# Out:
# Data Range 1:
# Element: 2, Count: 7
# Element: 7, Count: 193
#
# Data Range 2:
# Element: 2, Count: 13
# Element: 7, Count: 187
#
# Data Range 3:
# Element: 2, Count: 13
# Element: 7, Count: 187
#
# Data Range 4:
# Element: 3, Count: 1
# Element: 2, Count: 6
# Element: 7, Count: 193
#
# Data Range 5:
# Element: 3, Count: 2
# Element: 2, Count: 5
# Element: 7, Count: 193
#
# Data Range 6:
# Element: 2, Count: 5
# Element: 7, Count: 195
#
# Data Range 7:
# Element: 3, Count: 6
# Element: 2, Count: 7
# Element: 7, Count: 187
#
# Data Range 8:
# Element: 3, Count: 6
# Element: 2, Count: 7
# Element: 7, Count: 187
#
# Data Range 9:
# Element: 3, Count: 2
# Element: 2, Count: 4
# Element: 7, Count: 194
#
# Data Range 10:
# Element: 3, Count: 1
# Element: 2, Count: 12
# Element: 7, Count: 187
#
# Data Range 11:
# Element: 3, Count: 8
# Element: 2, Count: 6
# Element: 7, Count: 186
#
# Data Range 12:
# Element: 3, Count: 2
# Element: 2, Count: 5
# Element: 7, Count: 193
#
# Data Range 13:
# Element: 3, Count: 2
# Element: 2, Count: 4
# Element: 7, Count: 194
#
# Data Range 14:
# Element: 3, Count: 1
# Element: 2, Count: 6
# Element: 7, Count: 193
#
# Data Range 15:
# Element: 3, Count: 2
# Element: 2, Count: 5
# Element: 7, Count: 193
#
# Data Range 16:
# Element: 3, Count: 4
# Element: 2, Count: 3
# Element: 7, Count: 193
#
# Data Range 17:
# Element: 3, Count: 2
# Element: 2, Count: 4
# Element: 7, Count: 194
#
# Data Range 18:
# Element: 3, Count: 2
# Element: 2, Count: 5
# Element: 7, Count: 193
#
# Data Range 19:
# Element: 3, Count: 5
# Element: 2, Count: 4
# Element: 7, Count: 191
#
# Data Range 20:
# Element: 2, Count: 12
# Element: 1, Count: 1
# Element: 7, Count: 187
#
# Data Range 21:
# Element: 2, Count: 12
# Element: 1, Count: 1
# Element: 7, Count: 187
#
# Data Range 22:
# Element: 2, Count: 5
# Element: 7, Count: 195
#
# Data Range 23:
# Element: 3, Count: 2
# Element: 2, Count: 3
# Element: 7, Count: 195
#
# Data Range 24:
# Element: 3, Count: 2
# Element: 2, Count: 11
# Element: 7, Count: 187
#
# Data Range 25:
# Element: 3, Count: 6
# Element: 2, Count: 7
# Element: 7, Count: 187
#
# Data Range 26:
# Element: 2, Count: 5
# Element: 7, Count: 195
#
# Data Range 27:
# Element: 2, Count: 13
# Element: 7, Count: 187
#
# Data Range 28:
# Element: 3, Count: 6
# Element: 2, Count: 7
# Element: 7, Count: 187
#
# Data Range 29:
# Element: 2, Count: 14
# Element: 7, Count: 186
#
# Data Range 30:
# Element: 2, Count: 6
# Element: 7, Count: 194
#
# Data Range 31:
# Element: 3, Count: 6
# Element: 2, Count: 8
# Element: 16, Count: 2
# Element: 7, Count: 184
#
# Data Range 32:
# Element: 3, Count: 3
# Element: 2, Count: 4
# Element: 7, Count: 193
#
# Data Range 33:
# Element: 2, Count: 14
# Element: 7, Count: 186
