# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
import pandas as pd
import scipy.linalg as la
from schnetpack.datasets import QM9

# Load best model where it was stored after training

model = torch.load("./qm9tut/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='./qm9tut/split.npz')


device = 'cpu'

converter = spk.data.AtomsConverter(device=device)

#Control excel sheets to output data

from xlwt import Workbook

wb1 = Workbook()
wb2 = Workbook()
wb3 = Workbook()
wb4 = Workbook()
wb5 = Workbook()
wb6 = Workbook()
wb7 = Workbook()
wb8 = Workbook()
wb9 = Workbook()
wb10 = Workbook()
wb11 = Workbook()
wb12 = Workbook()
wb13 = Workbook()

sheet1 = wb1.add_sheet('Sheet1')
sheet2 = wb2.add_sheet('Sheet2')
sheet3 = wb3.add_sheet('Sheet3')
sheet4 = wb4.add_sheet('Sheet4')
sheet5 = wb5.add_sheet('Sheet5')
sheet6 = wb6.add_sheet('Sheet6')
sheet7 = wb7.add_sheet('Sheet7')
sheet8 = wb8.add_sheet('Sheet8')
sheet9 = wb9.add_sheet('Sheet9')
sheet10 = wb10.add_sheet('Sheet10')
sheet11 = wb11.add_sheet('Sheet10')
sheet12 = wb12.add_sheet('Sheet10')
sheet13 = wb13.add_sheet('Sheet10')

#Write the number of molecules you will evaluate (important for PCA)

#Some important counters for coding output into excel sheets 
index1=0
index2=0
index3=0
index4=0
index5=0
index6=0
index7=0
index8=0
index9=0
index10=0
index11=0
index12=0
index13=0

#BEGIN AUTOMATED CALCULATIONS, choose the range of QM9 to perform the calculations in
for idx in range(0,200):

# Load test set
    test_loader = spk.AtomsLoader(test, batch_size=100)
    converter = spk.data.AtomsConverter(device=device)
    
# Get properties of QM9
    at, props = qm9data.get_properties(idx)

    x = props['_positions'][ :,0]
    y = props['_positions'][ :,1]
    z = props['_positions'][ :,2]
    x = x.numpy()
    y = y.numpy()
    z = z.numpy()

    inputs = converter(at)
    print('Keys:', list(inputs.keys()))
    print('Truth:', props[QM9.U0].cpu().numpy()[0])

# Calculate prediction by best_model using schnetpack calculator 
    calculator = spk.interfaces.SpkCalculator(model=model, device=device, energy=QM9.U0)
    at.set_calculator(calculator)

# Print energy prediction and index of molecule
    print('Prediction:', at.get_total_energy())
    print('idx',idx)

    
# Output atomization energies of each atom in the molecule
    import numpy as np

    from schnetpack.atomistic import output_modules

    atomenergies = (output_modules.yi)

    atomenergies = atomenergies.detach().numpy()
    atomenergies = atomenergies.astype(float)
    print(atomenergies[0][1])

    Z = props['_atomic_numbers']

    Z= Z.cpu().detach().numpy() 
     


# Write the xyz matrix for each molecule
    j = len(props['_positions'])
    print('number of atoms', j)
    for i in range(j):
        if props['_atomic_numbers'][i] == 1:
            print('H',x[i],y[i],z[i])
        if props['_atomic_numbers'][i] == 6:
            print('C',x[i],y[i],z[i])
        if props['_atomic_numbers'][i] == 7:
            print('N',x[i],y[i],z[i])     
        if props['_atomic_numbers'][i] == 8:
            print('O',x[i],y[i],z[i])
        if props['_atomic_numbers'][i] == 9:
            print('F',x[i],y[i],z[i]) 

# Extract atomenergies into a 1D array
    AE = np.zeros(len(z))
    for i in range(len(z)):
        AE[i] = atomenergies[0][i]
    print(AE)


# Import internal stuff from schnet to do PCA on
    from schnetpack.representation.schnet import x
    embed=x.clone()
    from schnetpack.representation.schnet import x0
    embed0=x0.clone()
    from schnetpack.representation.schnet import v
    from schnetpack.nn.cfconv import W
    filt=W.clone()
    from schnetpack.nn.activations import soft

    
# convert embed to a 2D array!
    emb = np.zeros((len(z),30))
    for i in range(len(z)):
        for j in range(30):
            emb[i,j] = embed[0][i][j]
# convert embed0 to a 2D array!
    emb0 = np.zeros((len(z),30))
    for i in range(len(z)):
        for j in range(30):
            emb0[i,j] = embed0[0][i][j]
#convert interaction layer to 2D array
    inter = np.zeros((len(z),30))
    for i in range(len(z)):
        for j in range(30):
            inter[i,j] = v[0][i][j]
#convert soft to 2D array
    softact = np.zeros((len(z),15))
    for i in range(len(z)):
        for j in range(15):
            softact[i,j] = soft[0][i][j]
    
    
    
#Initial embedding vs final embedding after three interactions    
    
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 1:
            place=i
            sheet1.write(index1,0,idx)
            for j in range(30):
                sheet1.write(index1,j+1,emb0[place,j])
            index1=index1+1
            break
    wb1.save('./pca/embedding0-H.xls')
    read_file = pd.read_excel (r'./pca/embedding0-H.xls')
    read_file.to_csv (r'./pca/embedding0-H.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 6:
            place=i
            sheet2.write(index2,0,idx)
            for j in range(30):
                sheet2.write(index1,j+1,emb0[place,j])
            index2=index2+1
            break
    wb2.save('./pca/embedding0-C.xls')
    read_file = pd.read_excel (r'./pca/embedding0-C.xls')
    read_file.to_csv (r'./pca/embedding0-C.csv', index = None, header=True)

    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 7:
            place=i
            sheet3.write(index3,0,idx)
            for j in range(30):
                sheet3.write(index3,j+1,emb0[place,j])
            index3=index3+1
            break
    wb3.save('./pca/embedding0-N.xls')
    read_file = pd.read_excel (r'./pca/embedding0-N.xls')
    read_file.to_csv (r'./pca/embedding0-N.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 8:
            place=i
            sheet4.write(index4,0,idx)
            for j in range(30):
                sheet4.write(index4,j+1,emb0[place,j])
            index4=index4+1
            break
    wb4.save('./pca/embedding0-O.xls')
    read_file = pd.read_excel (r'./pca/embedding0-O.xls')
    read_file.to_csv (r'./pca/embedding0-O.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 8:
            place=i
            sheet5.write(index5,0,idx)
            for j in range(30):
                sheet5.write(index5,j+1,emb[place,j])
            index5=index5+1
            break
    wb5.save('./pca/embedding-O.xls')
    read_file = pd.read_excel (r'./pca/embedding-O.xls')
    read_file.to_csv (r'./pca/embedding-O.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 8:
            place=i
            sheet6.write(index6,0,idx)
            for j in range(30):
                sheet6.write(index6,j+1,inter[place,j])
            index6=index6+1
            break
    wb6.save('./pca/interaction-O.xls')
    read_file = pd.read_excel (r'./pca/interaction-O.xls')
    read_file.to_csv (r'./pca/interaction-O.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 8:
            place=i
            sheet7.write(index7,0,idx)
            for j in range(15):
                sheet7.write(index7,j+1,softact[place,j])
            index7=index7+1
            break
    wb7.save('./pca/softplus-O.xls')
    read_file = pd.read_excel (r'./pca/softplus-O.xls')
    read_file.to_csv (r'./pca/softplus-O.csv', index = None, header=True)
    
    
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 1:
            place=i
            sheet8.write(index8,0,idx)
            for j in range(30):
                sheet8.write(index8,j+1,emb[place,j])
            index8=index8+1
            break
    wb8.save('./pca/embedding-H.xls')
    read_file = pd.read_excel (r'./pca/embedding-H.xls')
    read_file.to_csv (r'./pca/embedding-H.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 1:
            place=i
            sheet9.write(index9,0,idx)
            for j in range(30):
                sheet9.write(index9,j+1,inter[place,j])
            index9=index9+1
            break
    wb9.save('./pca/interaction-H.xls')
    read_file = pd.read_excel (r'./pca/interaction-H.xls')
    read_file.to_csv (r'./pca/interaction-H.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 1:
            place=i
            sheet10.write(index10,0,idx)
            for j in range(15):
                sheet10.write(index10,j+1,softact[place,j])
            index10=index10+1
            break
    wb10.save('./pca/softplus-H.xls')
    read_file = pd.read_excel (r'./pca/softplus-H.xls')
    read_file.to_csv (r'./pca/softplus-H.csv', index = None, header=True)

    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 7:
            place=i
            sheet11.write(index11,0,idx)
            for j in range(30):
                sheet11.write(index11,j+1,emb[place,j])
            index11=index11+1
            break
    wb11.save('./pca/embedding-N.xls')
    read_file = pd.read_excel (r'./pca/embedding-N.xls')
    read_file.to_csv (r'./pca/embedding-N.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 7:
            place=i
            sheet12.write(index12,0,idx)
            for j in range(30):
                sheet12.write(index12,j+1,inter[place,j])
            index12=index12+1
            break
    wb12.save('./pca/interaction-N.xls')
    read_file = pd.read_excel (r'./pca/interaction-N.xls')
    read_file.to_csv (r'./pca/interaction-N.csv', index = None, header=True)
    for i in range(len(z)):
        if props['_atomic_numbers'][i] == 7:
            place=i
            sheet13.write(index13,0,idx)
            for j in range(15):
                sheet13.write(index13,j+1,softact[place,j])
            index13=index13+1
            break
    wb13.save('./pca/softplus-N.xls')
    read_file = pd.read_excel (r'./pca/softplus-N.xls')
    read_file.to_csv (r'./pca/softplus-N.csv', index = None, header=True)
# Out:
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -1101.4878
# hello
# Prediction: -1101.466796875
# idx 0
# [-17.07192421]
# number of atoms 5
# C -2.8340169e-06 2.3049886e-06 -1.4378233e-07
# H 0.014845718 -1.0918331 -0.0060250196
# H 1.0244261 0.3779494 -0.007724565
# H -0.52811974 0.36172476 -0.88464487
# H -0.5111183 0.3521308 0.89839613
# [-1033.17919922   -17.07192421   -17.07192421   -17.07192421
#    -17.07192421]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -1538.1477
# hello
# Prediction: -1538.0333251953125
# idx 1
# [-16.49673271]
# number of atoms 4
# N -0.03160822 0.021159047 0.060332563
# H 0.026075294 -0.9904034 -0.029608395
# H 0.9246072 0.35579658 -0.030988995
# H -0.5114599 0.34058344 -0.77777386
# [-1488.54309082   -16.49673271   -16.4967308    -16.4968338 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -2079.078
# hello
# Prediction: -2078.98876953125
# idx 2
# [-16.71058464]
# number of atoms 3
# O -0.056248687 0.035458494 0.0007260183
# H 0.042878296 -0.9215089 -0.00534094
# H 0.84990215 0.35871136 -0.0061824406
# [-2045.56750488   -16.71058464   -16.71058464]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -2103.6694
# hello
# Prediction: -2103.889892578125
# idx 3
# [-1034.22839355]
# number of atoms 4
# C 0.5995395 0.0 0.0
# C -0.5995395 0.0 0.0
# H -1.6616386 0.0 0.0
# H 1.6616386 0.0 0.0
# [-1034.22839355 -1034.22839355   -17.71651077   -17.71651077]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -2541.867
# hello
# Prediction: -2542.020751953125
# idx 4
# [-1490.48120117]
# number of atoms 3
# C -0.0075630867 0.5570853 0.003070365
# N 0.008071566 -0.59453905 -0.0032767907
# H -0.022041854 1.6235689 0.008948269
# [-1033.96142578 -1490.48120117   -17.57816696]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3115.2578
# hello
# Prediction: -3115.8388671875
# idx 5
# [-2047.43688965]
# number of atoms 4
# C -0.008137181 0.5992856 0.002790173
# O 0.0081545 -0.60058945 -0.0028012523
# H 0.9208008 1.2085854 -0.0010057696
# H -0.9532692 1.1830921 0.012220519
# [-1033.51171875 -2047.43688965   -17.44505692   -17.44505882]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -2170.4932
# hello
# Prediction: -2170.732177734375
# idx 6
# [-1033.43444824]
# number of atoms 8
# C -0.010403622 0.7647314 0.004216852
# C 0.010404125 -0.7647325 -0.004217135
# H 1.0031731 1.1788927 -0.0032747546
# H -0.53377575 1.1627601 -0.8713333
# H -0.5169408 1.1533226 0.89380807
# H 0.5337869 -1.1627584 0.871328
# H -1.0031761 -1.1788844 0.0032925315
# H 0.5169266 -1.1533209 -0.8938171
# [-1033.43444824 -1033.43444824   -17.31053352   -17.31053352
#    -17.31054306   -17.31053352   -17.31053352   -17.31054306]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3147.7896
# hello
# Prediction: -3147.843994140625
# idx 7
# [-2046.1105957]
# number of atoms 6
# C -0.013109998 0.7242496 0.009729234
# O -0.012792213 -0.6912656 0.03563598
# H 1.0017616 1.1493435 0.018813275
# H -0.5513966 1.1329496 -0.85857135
# H -0.52771056 1.0593323 0.91440314
# H 0.43659836 -0.99976444 -0.7561907
# [-1033.12475586 -2046.1105957    -17.2082634    -17.20814705
#    -17.14465523   -17.0472641 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3173.1074
# hello
# Prediction: -3173.42529296875
# idx 8
# [-1034.9239502]
# number of atoms 7
# C -0.017661946 1.2960836 0.0071456935
# C 0.002247235 -0.1587665 -0.00093627773
# C 0.018499928 -1.3600794 -0.00745336
# H 0.9979812 1.7059792 -0.0003422127
# H -0.54204524 1.6897374 -0.8701602
# H -0.52517396 1.6800693 0.8985331
# H 0.032475654 -2.4214225 -0.013208263
# [-1033.74084473 -1034.9239502  -1034.69226074   -17.42318535
#    -17.42318535   -17.42319107   -17.79899979]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3611.4448
# hello
# Prediction: -3611.564697265625
# idx 9
# [-1034.49182129]
# number of atoms 6
# C -0.017489549 1.2893138 0.0070837247
# C 0.0021349336 -0.16746153 -0.00095350837
# N 0.018049099 -1.3223433 -0.007233838
# H 1.0024261 1.6830851 -0.0005753772
# H -0.54359174 1.6669849 -0.873784
# H -0.5266811 1.6573676 0.9018339
# [-1033.70288086 -1034.49182129 -1491.1496582    -17.40674782
#    -17.40675163   -17.40675735]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4184.774
# hello
# Prediction: -4184.95654296875
# idx 10
# [-1033.67529297]
# number of atoms 7
# C -0.32895076 1.2171274 0.1722615
# C -0.2999231 -0.2895106 0.12612961
# O 0.6162821 -0.9478566 -0.29323703
# H 0.5967821 1.6335561 -0.22787684
# H -1.1880213 1.5857385 -0.40120664
# H -0.4765123 1.5511476 1.2064798
# H -1.220436 -0.7792203 0.5213374
# [-1033.60656738 -1033.67529297 -2047.82983398   -17.35688782
#    -17.41699028   -17.41689873   -17.65406036]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4622.1475
# hello
# Prediction: -4622.30322265625
# idx 11
# [-1033.47949219]
# number of atoms 6
# N -0.38758835 1.0900147 0.009073753
# C -0.31522122 -0.2678744 0.001384092
# O 0.71014667 -0.9087188 -0.010953284
# H 0.4636665 1.6289185 0.003917535
# H -1.2700653 1.5706655 0.019099763
# H -1.3231295 -0.7311347 0.008253755
# [-1489.37902832 -1033.47949219 -2047.72851562   -17.14266968
#    -17.13271904   -17.44102478]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3239.5828
# hello
# Prediction: -3239.766845703125
# idx 12
# [-1033.54907227]
# number of atoms 11
# C -0.2706059 1.1910484 0.45680413
# C -0.22731416 -0.3388451 0.40885028
# C 0.4822237 -0.875601 -0.83742285
# H 0.7400923 1.6148237 0.45586655
# H -0.79786986 1.5985445 -0.41327786
# H -0.7819902 1.5517678 1.3549396
# H 0.2757603 -0.71816975 1.3071942
# H -1.250174 -0.7343374 0.4454007
# H 1.5190445 -0.5235333 -0.8838322
# H 0.5014043 -1.9700171 -0.8502822
# H -0.019234117 -0.5402792 -1.7524073
# [-1033.59033203 -1033.54907227 -1033.59033203   -17.33830833
#    -17.33829689   -17.35663986   -17.48503685   -17.48503685
#    -17.33829689   -17.35663986   -17.33830833]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4217.023
# hello
# Prediction: -4217.2822265625
# idx 13
# [-1033.28991699]
# number of atoms 9
# C -0.24923308 1.1923306 0.41987085
# C -0.22963494 -0.32735643 0.41291267
# O 0.44026038 -0.7501257 -0.76644903
# H 0.7709053 1.5869126 0.4074815
# H -0.7722267 1.5710535 -0.46306357
# H -0.75737375 1.5664101 1.3137904
# H 0.2831432 -0.6988306 1.3149239
# H -1.2609035 -0.7147803 0.44358975
# H 0.45466772 -1.7115033 -0.7748019
# [-1033.59020996 -1033.28991699 -2046.37609863   -17.33340263
#    -17.33342361   -17.35669708   -17.43204498   -17.43201256
#    -17.13745689]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4216.686
# hello
# Prediction: -4216.85302734375
# idx 14
# [-2047.17041016]
# number of atoms 9
# C -0.22729343 1.1085668 0.38149688
# O -0.21718735 -0.29745212 0.3904224
# C 0.42547697 -0.8371423 -0.73775655
# H 0.79281163 1.5263125 0.38048214
# H -0.7593676 1.5095898 -0.49668467
# H -0.7425009 1.4390742 1.2868427
# H -0.07253405 -0.53983885 -1.6751579
# H 1.4801807 -0.52252936 -0.79895157
# H 0.3871224 -1.9256471 -0.6482503
# [-1033.21582031 -2047.17041016 -1033.21582031   -17.22234344
#    -17.22233009   -17.18093491   -17.22234344   -17.22232819
#    -17.18093491]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -3206.176
# hello
# Prediction: -3206.53515625
# idx 15
# [-1033.77770996]
# number of atoms 9
# C -0.44518742 0.7473952 0.008267543
# C 0.8697365 0.0119289 -0.008227876
# C -0.4245829 -0.7592663 -3.9128077e-05
# H -0.7386693 1.2500844 0.9232829
# H -0.75600964 1.2598648 -0.89552784
# H 1.4516793 0.024513466 -0.9232434
# H 1.4690117 0.014717146 0.89561427
# H -0.70413506 -1.279828 0.9093253
# H -0.72147447 -1.2700409 -0.9094577
# [-1033.77770996 -1033.77770996 -1033.77770996   -17.53372574
#    -17.53372765   -17.5337944    -17.5337944    -17.53375053
#    -17.53375053]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4183.5483
# hello
# Prediction: -4183.97265625
# idx 16
# [-1033.4552002]
# number of atoms 7
# C -0.4028922 0.7448623 0.007871166
# C 0.8465122 -0.023541624 -0.008242139
# O -0.4185096 -0.6804915 0.00034884654
# H -0.73590267 1.2130845 0.93306583
# H -0.7535452 1.2229853 -0.9056675
# H 1.4141974 -0.110212974 -0.9336246
# H 1.4318132 -0.1201021 0.90510976
# [-1033.4552002  -1033.4552002  -2047.31408691   -17.43689728
#    -17.43689537   -17.43689346   -17.43689537]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5254.201
# hello
# Prediction: -5254.24755859375
# idx 17
# [-1034.05407715]
# number of atoms 10
# C -0.048322067 1.4560183 -0.17357557
# C -0.09049219 -0.05335558 0.00041801704
# C 1.2518378 -0.74642915 0.16791351
# O -1.1316519 -0.66721845 0.0053270245
# H 0.5488151 1.7222008 -1.0532273
# H -1.0606242 1.8458552 -0.28479958
# H 0.43577582 1.926221 0.69001687
# H 1.7799013 -0.3491923 1.0423096
# H 1.1037049 -1.8204619 0.284567
# H 1.8916062 -0.5539819 -0.70093095
# [-1033.69018555 -1034.05407715 -1033.69018555 -2048.23413086
#    -17.4490509    -17.39125633   -17.44905663   -17.44905281
#    -17.39125633   -17.44905853]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5691.5146
# hello
# Prediction: -5691.69140625
# idx 18
# [-1033.68103027]
# number of atoms 9
# C -0.041906178 1.4559873 0.09754338
# C -0.076108925 -0.06123052 -0.025734434
# N 1.1295615 -0.67695296 0.18013088
# O -1.0859247 -0.6835165 -0.28406203
# H 0.8651978 1.8855276 -0.337787
# H -0.919514 1.8675319 -0.40023807
# H -0.07696631 1.7414627 1.1547049
# H 1.9353462 -0.17546864 0.50996274
# H 1.1417891 -1.6829057 0.22327578
# [-1033.65734863 -1033.68103027 -1489.51037598 -2048.19799805
#    -17.45724106   -17.37417221   -17.438694     -17.23622894
#    -17.13884926]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6128.588
# hello
# Prediction: -6129.0205078125
# idx 19
# [-1033.48168945]
# number of atoms 8
# N -0.019610332 1.3329531 -0.12559217
# C -0.08157441 -0.048591148 0.00057829724
# N 1.1640218 -0.65116775 0.118204065
# O -1.1238916 -0.6695715 0.0072275763
# H 0.75183135 1.8067259 0.320021
# H -0.9139208 1.7759094 0.021009542
# H 1.9436085 -0.20085609 -0.33745313
# H 1.1263803 -1.6493046 -0.022520492
# [-1489.47827148 -1033.48168945 -1489.47827148 -2048.01855469
#    -17.19459724   -17.08706284   -17.19460678   -17.08705902]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4308.715
# hello
# Prediction: -4308.86865234375
# idx 20
# [-1033.72241211]
# number of atoms 14
# C -0.40749285 1.4066033 0.011561046
# C -0.34151652 -0.12615411 0.0026236486
# C 0.33842176 -0.6421767 -1.272153
# C 0.36315602 -0.6558215 1.2583256
# H 0.5998934 1.8405308 0.0061001056
# H -0.93730164 1.7887106 -0.86753774
# H -0.9235064 1.7790715 0.9028968
# H -1.3728592 -0.5067184 0.010589452
# H 1.3753663 -0.28948048 -1.3318799
# H 0.35913295 -1.7368956 -1.2985805
# H -0.18166384 -0.29446852 -2.1711385
# H -0.13921405 -0.3174328 2.170869
# H 0.38430685 -1.7507441 1.2730775
# H 1.4010247 -0.3034658 1.3013467
# [-1033.68286133 -1033.72241211 -1033.6829834  -1033.68286133
#    -17.36589813   -17.39134598   -17.39125443   -17.65274811
#    -17.3656044    -17.3913517    -17.39142418   -17.39128876
#    -17.39130211   -17.36581421]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5286.281
# hello
# Prediction: -5286.5859375
# idx 21
# [-1033.3848877]
# number of atoms 12
# C 0.16795558 1.4243842 -0.31935304
# C 0.19002895 -0.10485057 -0.29820374
# C 0.91049814 -0.6594086 0.9248196
# O -1.1310841 -0.64056706 -0.26260433
# H 1.1832712 1.8337176 -0.34678715
# H -0.36276668 1.7974348 -1.2034236
# H -0.3397112 1.809968 0.57079
# H 0.7115355 -0.46111393 -1.2031567
# H 0.42351922 -0.3113001 1.8415376
# H 0.88353455 -1.7523178 0.9180865
# H 1.9554573 -0.335911 0.940277
# H -1.6170725 -0.27921587 -1.0105046
# [-1033.70263672 -1033.3848877  -1033.7166748  -2046.58740234
#    -17.36640167   -17.42865753   -17.34615898   -17.64646912
#    -17.3731575    -17.37644386   -17.39475441   -17.26290321]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4175.855
# hello
# Prediction: -4175.96240234375
# idx 22
# [-1035.70715332]
# number of atoms 6
# C 0.6809802 0.0 0.0
# C -0.6809802 0.0 0.0
# C -1.887666 0.0 0.0
# C 1.887666 0.0 0.0
# H -2.9496 0.0 0.0
# H 2.9496 0.0 0.0
# [-1035.70715332 -1035.70715332 -1034.51135254 -1034.51135254
#    -17.76267624   -17.76267624]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4613.9014
# hello
# Prediction: -4614.28125
# idx 23
# [-1035.55200195]
# number of atoms 5
# C -0.6873232 0.0 1.110223e-16
# C 0.6799044 0.0 1.110223e-16
# C -1.8910524 0.0 1.110223e-16
# H -2.954199 0.0 1.110223e-16
# N 1.8405347 0.0 1.110223e-16
# [-1035.51159668 -1035.55200195 -1034.55187988   -17.75979996
#  -1490.90625   ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5051.754
# hello
# Prediction: -5052.46875
# idx 24
# [-1035.27770996]
# number of atoms 4
# N 0.024680035 -1.8457185 -0.009939963
# C 0.009754817 -0.6878192 -0.0039871475
# C -0.0088915005 0.6878335 0.0035621906
# N -0.02542033 1.8457063 0.010304364
# [-1490.95666504 -1035.27770996 -1035.27770996 -1490.95666504]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5187.1606
# hello
# Prediction: -5187.53466796875
# idx 25
# [-1034.3984375]
# number of atoms 6
# O -0.8580772 -1.3778391 0.0013091499
# C -0.7959455 -0.17167185 0.005922886
# C 0.43953663 0.5778992 -0.0012279256
# C 1.4459372 1.2388089 -0.0068085077
# H -1.707023 0.45917478 0.016297776
# H 2.3439806 1.808202 -0.011892298
# [-2047.74145508 -1034.3984375  -1035.30810547 -1034.61486816
#    -17.71804047   -17.75334358]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5625.1885
# hello
# Prediction: -5625.59130859375
# idx 26
# [-1034.16137695]
# number of atoms 5
# O -0.83661675 -1.3895576 0.0010744806
# C -0.8137457 -0.18963368 0.005869432
# C 0.4370984 0.5822472 -0.0011569314
# N 1.4025168 1.2189847 -0.0064238496
# H -1.7223324 0.43802574 0.01605794
# [-2047.76330566 -1034.16137695 -1034.96166992 -1490.99401855
#    -17.71041679]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6198.7207
# hello
# Prediction: -6198.94384765625
# idx 27
# [-1034.02648926]
# number of atoms 6
# O -0.6208464 -1.6154674 -0.0022703465
# C -0.6413494 -0.4131876 0.0029220288
# C 0.64134026 0.41319242 -0.0039194413
# O 0.62085307 1.6154643 0.0029703435
# H -1.5711225 0.19277982 0.014684269
# H 1.5711266 -0.19278784 -0.013909801
# [-2047.77990723 -1034.02648926 -1034.02648926 -2047.77990723
#    -17.66543198   -17.66543388]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4242.4985
# hello
# Prediction: -4242.6884765625
# idx 28
# [-1035.36853027]
# number of atoms 10
# C -0.027913883 2.0577686 0.011311069
# C -0.008167857 0.6017288 0.003310354
# C 0.008162743 -0.601729 -0.003307965
# C 0.027917407 -2.0577683 -0.01131266
# H 0.8545688 2.4668994 0.51599646
# H -0.04221053 2.4631054 -1.0067108
# H -0.9123655 2.442855 0.5312388
# H -0.8448044 -2.4723904 0.5057136
# H 0.022729926 -2.452156 -1.033713
# H 0.92210054 -2.4483168 0.48746532
# [-1033.71899414 -1035.36853027 -1035.36853027 -1033.71899414
#    -17.41903687   -17.41903687   -17.41903687   -17.41903687
#    -17.41903687   -17.41903687]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4242.1826
# hello
# Prediction: -4242.408203125
# idx 29
# [-1033.93347168]
# number of atoms 10
# C -0.47994632 1.4412258 0.82309425
# C -0.43413416 -0.096899785 0.7705933
# C 0.24200283 -0.6060703 -0.4171614
# C 0.8032349 -1.0016692 -1.403864
# H 0.5300051 1.8596916 0.8251531
# H -1.0098115 1.8435045 -0.044392645
# H -0.99475497 1.7757307 1.7285055
# H 0.07021343 -0.4807785 1.6663771
# H -1.455436 -0.49683288 0.80482113
# H 1.2969575 -1.3625664 -2.2715795
# [-1033.55126953 -1033.93347168 -1035.1607666  -1034.6418457
#    -17.3457737    -17.3457737    -17.36968994   -17.62985229
#    -17.62984848   -17.80030251]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4680.5254
# hello
# Prediction: -4680.6767578125
# idx 30
# [-1033.88024902]
# number of atoms 9
# C -0.47349352 1.4569983 0.81068796
# C -0.4364341 -0.08073943 0.77378726
# C 0.24087769 -0.59910065 -0.4139606
# N 0.77738386 -0.99434066 -1.3580205
# H 0.53744274 1.8713977 0.8130558
# H -1.0034953 1.8552644 -0.05776344
# H -0.98789907 1.7922113 1.7147204
# H 0.076545596 -0.4729927 1.6586878
# H -1.4528089 -0.4890533 0.79465497
# [-1033.5880127  -1033.88024902 -1034.86706543 -1491.09204102
#    -17.33094406   -17.33091927   -17.35500336   -17.61602402
#    -17.6159668 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5116.8853
# hello
# Prediction: -5117.01708984375
# idx 31
# [-1033.47424316]
# number of atoms 8
# N 0.8523535 1.4091179 0.030611413
# C 0.8780398 -0.053331316 -0.02123539
# C -0.4833751 -0.59959656 0.02122341
# N -1.5518323 -1.0380719 0.02753588
# H 1.805732 1.756968 0.045857508
# H 0.41681272 1.7782646 -0.80892503
# H 1.3778961 -0.48731136 -0.903321
# H 1.416706 -0.42384073 0.8585262
# [-1489.11437988 -1033.47424316 -1034.61413574 -1491.16943359
#    -16.89706802   -16.96066856   -17.43729591   -17.35007858]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5219.441
# hello
# Prediction: -5219.70751953125
# idx 32
# [-1033.59069824]
# number of atoms 8
# O 0.8357715 1.3373044 -0.00080194796
# C 0.8575883 -0.084277265 -0.008656541
# C -0.5077634 -0.5948881 0.0016466676
# C -1.623125 -1.0397791 0.009920608
# H 1.7503725 1.6372886 -0.007630262
# H 1.3756938 -0.4718312 -0.90070695
# H 1.392608 -0.48135367 0.86910504
# H -2.6118317 -1.4274471 0.017277308
# [-2046.33337402 -1033.59069824 -1034.9239502  -1034.77416992
#    -17.18771553   -17.55850029   -17.55845642   -17.78078461]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5657.704
# hello
# Prediction: -5657.91162109375
# idx 33
# [-1033.51000977]
# number of atoms 7
# O 0.8167186 1.3475205 -0.00062532997
# C 0.86702985 -0.06354135 -0.008641366
# C -0.50337374 -0.5867032 0.0016643667
# N -1.567252 -1.0348098 0.009427512
# H 1.7230814 1.6717715 -0.0065572513
# H 1.371028 -0.46125588 -0.90289116
# H 1.387977 -0.47074544 0.8715062
# [-2046.35827637 -1033.51000977 -1034.59069824 -1491.21813965
#    -17.17266655   -17.53072548   -17.53060913]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5253.8438
# hello
# Prediction: -5254.078125
# idx 34
# [-1033.77697754]
# number of atoms 10
# C -0.25688466 1.5916414 -0.86591065
# C -0.61305434 0.1284587 -0.56164634
# C 0.08349835 -0.37345108 0.6828184
# O 0.7562327 -1.3691448 0.7497238
# H 0.805587 1.6978836 -1.104767
# H -0.83312476 1.9608278 -1.7181325
# H -0.47498843 2.2391737 -0.009865776
# H -1.6947297 0.049830392 -0.37989575
# H -0.36288747 -0.53599375 -1.3931805
# H -0.071829684 0.27314475 1.5802705
# [-1033.59118652 -1033.77697754 -1034.00354004 -2047.8013916
#    -17.33246422   -17.35664177   -17.35548592   -17.62658882
#    -17.55088234   -17.68347168]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5691.123
# hello
# Prediction: -5691.142578125
# idx 35
# [-1490.0534668]
# number of atoms 9
# C -0.29365814 1.3020542 -0.8425833
# N -0.12132652 -0.13851523 -0.8365585
# C 0.14862932 -0.8454173 0.29319996
# O 0.27617267 -0.3755904 1.4037071
# H 0.45184562 1.7905327 -1.4794713
# H -1.2930315 1.5830164 -1.1923411
# H -0.1657088 1.6470488 0.18400396
# H -0.2045438 -0.64620566 -1.7021039
# H 0.24206837 -1.9293629 0.08119238
# [-1033.22167969 -1490.0534668  -1033.7689209  -2047.75891113
#    -17.18086624   -17.18091965   -17.13019562   -17.35161209
#    -17.49620819]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6231.7827
# hello
# Prediction: -6231.740234375
# idx 36
# [-2047.75354004]
# number of atoms 8
# C -0.34122062 1.6519755 0.5416211
# O -0.020892803 0.26402432 0.60135955
# C 0.059390184 -0.41967162 -0.5549229
# O 0.3215117 -1.5826951 -0.6018447
# H 0.47573406 2.2207065 0.99291736
# H -0.4853366 1.9861269 -0.49231416
# H -1.2604542 1.8248742 1.106993
# H -0.14317384 0.214536 -1.4413954
# [-1033.10534668 -2047.75354004 -1034.11608887 -2047.64355469
#    -17.18844604   -17.21940994   -17.18844414   -17.52532387]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6231.2065
# hello
# Prediction: -6231.37646484375
# idx 37
# [-1033.45410156]
# number of atoms 8
# O 0.9053031 1.4252946 0.50014365
# C 0.7614709 0.06763947 0.1408983
# C -0.6973357 -0.34277213 -0.01985505
# O -1.0657501 -1.318754 -0.6174562
# H 0.6943127 1.966276 -0.2672169
# H 1.3159493 -0.211613 -0.76589656
# H 1.1789486 -0.52163213 0.9679234
# H -1.406806 0.35434428 0.48486584
# [-2046.34631348 -1033.45410156 -1033.90026855 -2047.84765625
#    -17.26812744   -17.47977066   -17.44499397   -17.63521194]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4308.677
# hello
# Prediction: -4308.853515625
# idx 38
# [-1033.73730469]
# number of atoms 14
# C -0.39021975 1.8088213 0.65719855
# C -0.35307074 0.27912098 0.62026554
# C 0.3530644 -0.2791212 -0.62026495
# C 0.39022544 -1.8088214 -0.6571987
# H 0.62180984 2.2292233 0.6553988
# H -0.9159678 2.2128956 -0.21531074
# H -0.9009811 2.1776998 1.5523278
# H 0.14914319 -0.09831827 1.521004
# H -1.3774784 -0.11465078 0.6594648
# H -0.14915404 0.098314516 -1.521002
# H 1.3774698 0.114655964 -0.65946597
# H 0.9160251 -2.2128918 0.21528102
# H -0.6218005 -2.2292323 -0.65534467
# H 0.90094143 -2.1776922 -1.5523572
# [-1033.60009766 -1033.73730469 -1033.73730469 -1033.60009766
#    -17.34388733   -17.34394836   -17.35591888   -17.52288628
#    -17.5227108    -17.52288818   -17.52270889   -17.34394646
#    -17.34388733   -17.35591888]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5286.1133
# hello
# Prediction: -5286.3974609375
# idx 39
# [-1033.75561523]
# number of atoms 12
# C 0.74676186 1.8234588 0.0026987367
# C 0.71465826 0.29370835 -0.0053245095
# C -0.7016382 -0.2650462 0.0052626343
# O -0.61744595 -1.6824552 -0.003045157
# H 1.7753277 2.1956031 -0.005183291
# H 0.23768522 2.239137 -0.8741201
# H 0.25471118 2.2295043 0.893636
# H 1.2319598 -0.093814634 -0.8907419
# H 1.2488378 -0.10337167 0.86572224
# H -1.2367903 0.09749595 0.8990794
# H -1.253763 0.106896155 -0.8742458
# H -1.5111663 -2.0367522 0.0027662576
# [-1033.59033203 -1033.75561523 -1033.45849609 -2046.38903809
#    -17.35142136   -17.34357643   -17.34358025   -17.51762772
#    -17.51761055   -17.48351669   -17.48339081   -17.16293907]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5285.924
# hello
# Prediction: -5286.13134765625
# idx 40
# [-1033.44116211]
# number of atoms 12
# C -0.37670365 1.7365772 -0.58901405
# C -0.35834232 0.21751666 -0.60221523
# O 0.32608134 -0.23554656 0.54658806
# C 0.3953768 -1.6371869 0.623925
# H 0.6429466 2.1321328 -0.59214145
# H -0.9014168 2.1197355 -1.4693707
# H -0.8841458 2.1059532 0.30665258
# H -1.3875031 -0.18209246 -0.6149588
# H 0.13942331 -0.15579951 -1.5142956
# H -0.6056665 -2.09662 0.6676761
# H 0.92978466 -2.0706418 -0.23724067
# H 0.9383948 -1.890225 1.5380305
# [-1033.56518555 -1033.44116211 -2047.39831543 -1033.22009277
#    -17.32952118   -17.36553001   -17.32956696   -17.42546082
#    -17.4254837    -17.22280502   -17.22280502   -17.1856842 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6263.6006
# hello
# Prediction: -6263.73779296875
# idx 41
# [-1033.4552002]
# number of atoms 10
# O 0.88869995 1.1945848 0.27268523
# C 0.8989689 -0.22466038 0.36188236
# C -0.5202829 -0.7874435 0.31435534
# O -1.2094069 -0.33747628 -0.8453615
# H 0.71300846 1.4097096 -0.6486298
# H 1.4994824 -0.6649918 -0.4471692
# H 1.3759985 -0.48087484 1.3143939
# H -0.49206132 -1.8815902 0.26408985
# H -1.0620868 -0.5040067 1.2282414
# H -1.4563725 0.57760644 -0.67922425
# [-2046.41491699 -1033.4552002  -1033.4552002  -2046.41491699
#    -17.25078011   -17.38304138   -17.36495209   -17.36495399
#    -17.38306236   -17.25083923]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4275.3643
# hello
# Prediction: -4275.6533203125
# idx 42
# [-1033.96801758]
# number of atoms 12
# C -0.5463674 1.4636921 -0.2262498
# C -0.4909601 -0.04719331 -0.19379187
# C 0.7985717 -0.7697573 -0.49114555
# C 0.24312928 -0.75991446 0.9137054
# H 0.39071193 1.8966556 0.14089198
# H -0.7067486 1.8371363 -1.2440271
# H -1.3571976 1.8486519 0.4025718
# H -1.394513 -0.53725624 -0.54760474
# H 0.758664 -1.6962681 -1.0534451
# H 1.6797624 -0.16854943 -0.6912165
# H 0.7521436 -0.15211189 1.6549588
# H -0.1749366 -1.6797266 1.3078655
# [-1033.67932129 -1033.96801758 -1033.91516113 -1033.91516113
#    -17.40106583   -17.38419533   -17.38418579   -17.71630096
#    -17.57998657   -17.56494904   -17.56492996   -17.57999229]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5252.875
# hello
# Prediction: -5253.19873046875
# idx 43
# [-1033.58935547]
# number of atoms 10
# C -0.5051477 1.4701715 0.23591569
# C -0.5161165 -0.03155866 0.11930383
# C 0.2842813 -0.74945444 -0.8804299
# O 0.6834387 -0.71516526 0.49098954
# H 0.42997557 1.8810065 -0.15465757
# H -1.3402644 1.9064294 -0.32289335
# H -0.6035613 1.777829 1.282179
# H -1.4245102 -0.5216416 0.47502917
# H -0.044245012 -1.7201506 -1.249905
# H 0.91669863 -0.18413898 -1.5645137
# [-1033.6583252  -1033.58935547 -1033.63720703 -2047.60046387
#    -17.36555481   -17.37056732   -17.37960243   -17.63806534
#    -17.48276711   -17.47636986]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4711.5913
# hello
# Prediction: -4711.80419921875
# idx 44
# [-1490.07116699]
# number of atoms 11
# C -0.5746446 1.3396131 -0.24876487
# N -0.502484 -0.11268311 -0.19540729
# C 0.8032212 -0.6990511 -0.47296318
# C 0.25862837 -0.6751625 0.91367173
# H 0.3459528 1.8371781 0.10421691
# H -0.76034075 1.6563674 -1.2801846
# H -1.4087237 1.684807 0.370748
# H 0.7980399 -1.6164504 -1.0547763
# H 1.6301389 -0.024380542 -0.6916084
# H 0.72374654 0.0153784 1.6162366
# H -0.15175563 -1.5747871 1.3635777
# [-1033.36535645 -1490.07116699 -1033.59313965 -1033.59313965
#    -17.25848389   -17.19543648   -17.19543648   -17.3690834
#    -17.39712143   -17.39712143   -17.3690834 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5252.7495
# hello
# Prediction: -5253.15478515625
# idx 45
# [-1033.6027832]
# number of atoms 10
# O 0.58268833 1.3023893 -0.39443073
# C 0.3831935 -0.07980648 -0.3166366
# C -0.023902148 -0.7664494 0.95567703
# C -0.98426884 -0.69428307 -0.22474378
# H -0.06951088 1.7391492 0.16258794
# H 1.1167241 -0.5755198 -0.9437273
# H 0.42650628 -1.7198842 1.2098128
# H -0.24678102 -0.13995937 1.8142269
# H -1.8313068 -0.020894999 -0.13336515
# H -1.1970466 -1.5978836 -0.7857448
# [-2046.55065918 -1033.6027832  -1033.86914062 -1033.86914062
#    -17.37783241   -17.60894394   -17.54298592   -17.59509659
#    -17.5951252    -17.54298401]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -4275.33
# hello
# Prediction: -4275.78125
# idx 46
# [-1033.8515625]
# number of atoms 12
# C -0.749253 0.7665048 -0.20637259
# C 0.8018206 0.7303789 -0.12300039
# C 0.69764394 -0.71235305 0.4442357
# C -0.7502117 -0.78453046 -0.11486227
# H -1.1897371 1.222578 0.6854158
# H -1.2028258 1.2264612 -1.087867
# H 1.2586594 0.73993236 -1.117245
# H 1.2980903 1.4860449 0.49100813
# H 1.4190933 -1.4533845 0.09110165
# H 0.70723516 -0.71630615 1.5384057
# H -1.5143578 -1.2591239 0.5057526
# H -0.7761558 -1.2462053 -1.106577
# [-1033.8515625  -1033.8515625  -1033.8515625  -1033.8515625
#    -17.55709648   -17.53683472   -17.55709648   -17.53683472
#    -17.53683472   -17.55709648   -17.53683472   -17.55709648]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5252.725
# hello
# Prediction: -5253.1708984375
# idx 47
# [-1033.54504395]
# number of atoms 10
# C -0.7670668 0.80218834 -0.18759951
# C 0.761323 0.7041908 -0.001375825
# O 0.69508994 -0.7269163 0.17002626
# C -0.73851645 -0.72804123 0.0069237044
# H -1.297961 1.3626112 0.5833927
# H -1.0984524 1.1435276 -1.1694459
# H 1.3681483 0.98485094 -0.8715061
# H 1.168062 1.2046599 0.88644487
# H -1.2520474 -1.1063579 0.8998369
# H -1.0518695 -1.3260804 -0.8581154
# [-1033.71972656 -1033.54504395 -2047.45117188 -1033.54504395
#    -17.54860687   -17.54860878   -17.45295715   -17.45295525
#    -17.45295715   -17.45295906]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6758.635
# hello
# Prediction: -6758.95556640625
# idx 48
# [-1034.03503418]
# number of atoms 12
# C -0.112086184 1.4519535 0.4722047
# C -0.0147302225 -0.050548814 0.4463064
# C -0.016417842 -0.8160251 1.7378886
# N 0.07233551 -0.7391456 -0.62733203
# O 0.06485818 0.08503627 -1.7684115
# H 0.7738884 1.8997909 0.0100006135
# H -0.9710368 1.7890232 -0.116678566
# H -0.20807421 1.8275121 1.4928572
# H -0.93573266 -0.6200971 2.303366
# H 0.06302906 -1.8877655 1.5487098
# H 0.81983924 -0.5026511 2.374872
# H 0.13022676 -0.5596606 -2.4803517
# [-1033.68835449 -1034.03503418 -1033.68591309 -1490.08544922
#  -2045.97619629   -17.41289139   -17.4076786    -17.41876793
#    -17.42589188   -17.3866291    -17.42415047   -17.00835419]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5717.1606
# hello
# Prediction: -5717.42236328125
# idx 49
# [-1034.29138184]
# number of atoms 10
# N -0.9180845 0.6395383 0.012588642
# C 0.37054497 1.1104841 0.0024043377
# C 1.2123789 0.022898844 -0.011827072
# C 0.3987115 -1.145186 -0.010212609
# C -0.9132154 -0.73245895 0.0049862936
# H -1.7422199 1.2136365 0.023858875
# H 0.5749306 2.1690361 0.006172064
# H 2.2908816 0.05934065 -0.022255225
# H 0.7383184 -2.169487 -0.019175014
# H -1.835304 -1.2910607 0.011022954
# [-1490.30078125 -1034.29138184 -1034.64355469 -1034.64355469
#  -1034.29138184   -17.62457275   -17.75414658   -18.05944824
#    -18.05945015   -17.75414658]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6154.15
# hello
# Prediction: -6154.18603515625
# idx 50
# [-1034.05786133]
# number of atoms 9
# N -0.90508646 0.6707805 0.012687857
# C 0.4002287 1.1101744 0.002209141
# C 1.1603798 -0.029206898 -0.011549963
# N 0.35873196 -1.1483326 -0.0099296365
# C -0.8721138 -0.69264513 0.00468077
# H -1.7270827 1.2506031 0.024005052
# H 0.65041405 2.1578689 0.0055698445
# H 2.2366488 -0.10988363 -0.022562245
# H -1.7718042 -1.2897266 0.010187248
# [-1490.20349121 -1034.05786133 -1034.17358398 -1491.08227539
#  -1034.04040527   -17.61784744   -17.75347137   -17.73072052
#    -17.52656937]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6257.779
# hello
# Prediction: -6257.8076171875
# idx 51
# [-1034.45629883]
# number of atoms 9
# O -0.9305199 0.639632 0.012419049
# C 0.35523072 1.0806578 0.0024417762
# C 1.218685 0.03273698 -0.0116696535
# C 0.40601626 -1.1495432 -0.010087874
# C -0.881666 -0.7187911 0.0046582264
# H 0.48154917 2.150592 0.0070196153
# H 2.2958024 0.08763578 -0.02184075
# H 0.74062717 -2.174852 -0.018824205
# H -1.8353246 -1.2200185 0.011184192
# [-2048.23144531 -1034.45629883 -1034.5958252  -1034.5958252
#  -1034.45629883   -17.70362091   -18.03204727   -18.03204727
#    -17.70362091]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6694.794
# hello
# Prediction: -6694.8046875
# idx 52
# [-1034.19824219]
# number of atoms 8
# O -0.91815954 0.6702991 0.012432184
# C 0.38489324 1.0824127 0.0020628197
# C 1.1694809 -0.019840097 -0.011380214
# N 0.36219412 -1.1534611 -0.009695154
# C -0.8398784 -0.6805247 0.004515949
# H 0.5550625 2.144812 0.006088491
# H 2.2452524 -0.08831028 -0.022127314
# H -1.7739537 -1.2195619 0.010649607
# [-2048.14208984 -1034.19824219 -1034.17370605 -1490.97912598
#  -1034.30810547   -17.67861176   -17.73091125   -17.59387779]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5377.8467
# hello
# Prediction: -5378.1142578125
# idx 53
# [-1034.01037598]
# number of atoms 17
# C -0.02066904 1.5389369 0.008411484
# C 2.4449399e-05 -6.2484316e-05 -1.7764884e-05
# C 0.74436074 -0.5098334 1.2468888
# C -1.4439805 -0.5326619 0.011127009
# C 0.72027093 -0.49642178 -1.2664438
# H 0.9956905 1.9482795 0.0023671836
# H -0.5438976 1.9324883 -0.8701867
# H -0.5296628 1.922958 0.89949775
# H 0.25341702 -0.17195304 2.1663432
# H 0.7760751 -1.6048495 1.2689015
# H 1.777569 -0.1456841 1.2674527
# H -2.0007977 -0.1848137 -0.86606824
# H -1.4616479 -1.6281981 0.0045115957
# H -1.982967 -0.19572215 0.90362823
# H 1.752746 -0.13146594 -1.3031684
# H 0.75189114 -1.5911661 -1.3002104
# H 0.21150348 -0.14936475 -2.1726592
# [-1033.74865723 -1034.01037598 -1033.7487793  -1033.74865723
#  -1033.74865723   -17.42569923   -17.42557335   -17.42555618
#    -17.4256649    -17.42557907   -17.42562485   -17.42557716
#    -17.42555046   -17.42576981   -17.42553711   -17.42567253
#    -17.42565918]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6355.5083
# hello
# Prediction: -6355.78466796875
# idx 54
# [-1033.51660156]
# number of atoms 15
# C -0.023475222 1.5470222 0.007835588
# C -0.009847433 0.011347052 0.02487002
# C 0.7464621 -0.5140713 1.2539729
# C -1.435043 -0.54501116 -0.014851667
# O 0.6109895 -0.47931674 -1.1702621
# H 0.99869883 1.9445285 0.0091197025
# H -0.5295119 1.9113454 -0.8907494
# H -0.53706336 1.9531459 0.88549185
# H 0.2663909 -0.19733478 2.1857443
# H 0.78473985 -1.6069968 1.2365339
# H 1.7760539 -0.13640866 1.2671385
# H -1.9534636 -0.19478653 -0.9119744
# H -1.4142915 -1.6382699 -0.039329913
# H -2.0034225 -0.22627586 0.8635737
# H 1.5161966 -0.15055977 -1.1857938
# [-1033.78625488 -1033.51660156 -1033.78637695 -1033.7947998
#  -2046.74816895   -17.47485352   -17.3965683    -17.40463257
#    -17.40463257   -17.39656639   -17.47486496   -17.42051697
#    -17.42050743   -17.43721581   -17.32298279]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6256.6396
# hello
# Prediction: -6256.998046875
# idx 55
# [-1034.86608887]
# number of atoms 9
# C 0.0027319437 1.6727747 0.3891572
# C -0.02019125 0.1612327 0.46227753
# O -0.07848194 -0.45497167 1.5031389
# C 0.033040263 -0.52538854 -0.82083297
# C 0.07705177 -1.0834044 -1.8864405
# H 0.9139685 2.0099978 -0.11676303
# H -0.84371483 2.0327482 -0.20573738
# H -0.042707186 2.088177 1.3967503
# H 0.114339136 -1.5931815 -2.8185353
# [-1033.65466309 -1034.86608887 -2048.20141602 -1035.66271973
#  -1034.56872559   -17.4438324    -17.44372559   -17.40136337
#    -17.75545692]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6694.746
# hello
# Prediction: -6695.0810546875
# idx 56
# [-1034.59155273]
# number of atoms 8
# C -0.008269734 1.6779771 0.40176994
# C -0.02575616 0.17485183 0.4854148
# O -0.08819905 -0.46769 1.501225
# C 0.041752275 -0.5186633 -0.8235829
# N 0.0948041 -1.0515871 -1.8483781
# H 0.9043725 2.011946 -0.10424663
# H -0.8531981 2.0268834 -0.20227875
# H -0.06072416 2.0995548 1.4059408
# [-1033.70690918 -1034.59155273 -2048.25708008 -1035.3145752
#  -1490.93725586   -17.43882561   -17.43883133   -17.39549637]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6693.9434
# hello
# Prediction: -6694.31640625
# idx 57
# [-1034.45874023]
# number of atoms 8
# N 0.34969485 1.5370883 0.004275708
# C 0.45671862 0.17811376 -0.0033606628
# O 1.5152369 -0.41716707 -0.016116131
# C -0.83179337 -0.5081382 0.0052160635
# C -1.8721521 -1.1103458 0.011935128
# H 1.1951828 2.0837114 -0.00076137955
# H -0.5431379 1.9977936 0.014995839
# H -2.783998 -1.656359 0.017823184
# [-1489.48059082 -1034.45874023 -2048.11645508 -1035.49902344
#  -1034.60705566   -17.18325615   -17.22757721   -17.74415398]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7268.2524
# hello
# Prediction: -7268.337890625
# idx 58
# [-1034.39978027]
# number of atoms 9
# C -0.60535604 1.4505482 0.28413415
# C 0.078761764 0.13441168 0.5431087
# O 0.5246256 -0.22422178 1.607767
# C 0.21569404 -0.8230552 -0.650542
# O -0.19020806 -0.57096136 -1.7541173
# H -0.074029736 1.9979265 -0.5016059
# H -1.6167997 1.2753751 -0.0975137
# H -0.64167094 2.040163 1.2000848
# H 0.72920346 -1.7709069 -0.38359973
# [-1033.69970703 -1034.39978027 -2048.23022461 -1034.22106934
#  -2047.81176758   -17.44406128   -17.44419098   -17.3949852
#    -17.69121552]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7705.414
# hello
# Prediction: -7705.416015625
# idx 59
# [-1034.04211426]
# number of atoms 8
# N 0.22514969 1.7170398 0.0064963438
# C 0.36954904 0.36228982 -0.0018013478
# O 1.4266587 -0.22401644 -0.014323427
# C -0.98531586 -0.37468112 0.0072250515
# O -1.0659329 -1.5683825 0.0021558576
# H 1.049561 2.2954257 0.0020048572
# H -0.67501855 2.1639411 0.017318206
# H -1.8913549 0.27758178 0.018901693
# [-1489.47241211 -1034.04211426 -2048.07202148 -1034.04858398
#  -2047.71264648   -17.15628815   -17.21387672   -17.69703484]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5311.3027
# hello
# Prediction: -5311.41015625
# idx 60
# [-1034.21289062]
# number of atoms 13
# C 0.54365075 1.592471 -0.28678378
# C 0.5440933 0.05123421 -0.2515519
# C 1.3194697 -0.4843252 0.9685407
# C -0.8208479 -0.47380808 -0.2764928
# C -1.9466788 -0.8961799 -0.27946243
# H 1.5707291 1.9702724 -0.31057626
# H 0.016138941 1.9660468 -1.1681826
# H 0.048855096 1.9972752 0.6013585
# H 1.0549469 -0.30516523 -1.1569068
# H 0.8509697 -0.1495774 1.8990988
# H 1.339619 -1.5771488 0.97358936
# H 2.35081 -0.11794095 0.95150155
# H -2.9386973 -1.2742254 -0.29148367
# [-1033.6340332  -1034.21289062 -1033.6340332  -1035.41955566
#  -1034.60131836   -17.40476418   -17.38615799   -17.36968422
#    -17.78738976   -17.36968803   -17.38615799   -17.4047699
#    -17.79911423]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -5749.6514
# hello
# Prediction: -5749.7177734375
# idx 61
# [-1034.1237793]
# number of atoms 12
# C -0.052667186 1.5881379 0.6377174
# C -0.06880968 0.047822926 0.60453784
# C -1.5006969 -0.5198824 0.64008904
# C 0.6510138 -0.4480523 -0.5745721
# N 1.2116657 -0.8334883 -1.5090418
# H 0.96935123 1.9745116 0.63065225
# H -0.5799721 1.9991958 -0.2278283
# H -0.5515862 1.9412478 1.5447142
# H 0.4745751 -0.32444516 1.4824102
# H -2.0745227 -0.17650776 -0.2253631
# H -1.4946266 -1.6124898 0.63469666
# H -2.0082986 -0.1794794 1.5471232
# [-1033.67700195 -1034.1237793  -1033.67700195 -1035.16503906
#  -1491.05285645   -17.37239456   -17.35312271   -17.38961792
#    -17.79185867   -17.35313988   -17.37241364   -17.38964081]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6186.184
# hello
# Prediction: -6186.24169921875
# idx 62
# [-1033.57922363]
# number of atoms 11
# C 0.5450326 1.5968091 -0.2746015
# C 0.55363744 0.06308237 -0.24318773
# N 1.3183624 -0.415496 0.9106862
# C -0.8297439 -0.46547034 -0.28376332
# N -1.9011331 -0.9008385 -0.2748727
# H 1.5761107 1.9565881 -0.27789873
# H 0.026943982 1.9674567 -1.1621372
# H 0.037180185 1.9970266 0.60830957
# H 1.0598638 -0.30253276 -1.1445831
# H 0.85638237 -0.12812711 1.7697307
# H 1.3371655 -1.4311808 0.9224594
# [-1033.66186523 -1033.57922363 -1489.28881836 -1034.96582031
#  -1491.0402832    -17.35820007   -17.35433006   -17.37552261
#    -17.54849243   -17.05900955   -17.00961685]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6288.779
# hello
# Prediction: -6288.91845703125
# idx 63
# [-1033.72949219]
# number of atoms 11
# C -0.024941536 1.5804 0.6270696
# C -0.005323342 0.045704123 0.5899224
# O -1.3089012 -0.5031127 0.7618272
# C 0.63353485 -0.45244792 -0.6337418
# C 1.121628 -0.8410348 -1.661492
# H 0.9908436 1.9844332 0.5898606
# H -0.5801212 1.9766587 -0.22921759
# H -0.5106804 1.9140329 1.5476044
# H 0.5607209 -0.3199105 1.4551519
# H -1.802564 -0.33429405 -0.048530698
# H 1.56339 -1.198912 -2.5586312
# [-1033.65527344 -1033.72949219 -2046.55566406 -1035.40161133
#  -1034.60388184   -17.38047218   -17.39785576   -17.37114334
#    -17.69179916   -17.36333847   -17.76799393]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6727.059
# hello
# Prediction: -6727.1533203125
# idx 64
# [-1033.65161133]
# number of atoms 10
# C 0.5316238 1.5948187 -0.28219584
# C 0.54895324 0.06251989 -0.23920514
# O 1.2624056 -0.45100507 0.86912805
# C -0.82840264 -0.47825956 -0.28057352
# N -1.9092673 -0.8870317 -0.28234872
# H 1.5604715 1.9616041 -0.26227635
# H 0.038933463 1.9549932 -1.1894974
# H -0.0064558904 1.9990758 0.5810188
# H 1.0775769 -0.31964225 -1.1192273
# H 0.81857485 -0.16114564 1.6746999
# [-1033.68566895 -1033.65161133 -2046.58959961 -1035.06481934
#  -1491.05505371   -17.35571098   -17.36048508   -17.38865852
#    -17.65534401   -17.3467083 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6322.972
# hello
# Prediction: -6323.04833984375
# idx 65
# [-1033.99829102]
# number of atoms 13
# C 0.48407435 1.6903256 -0.08229043
# C 0.5250599 0.15250751 -0.07279259
# C 1.2577494 -0.38233417 1.1697518
# C -0.89174175 -0.38703817 -0.090031154
# O -1.3658336 -1.084269 -0.94844854
# H 1.4986078 2.0978053 -0.03739774
# H 0.003119928 2.0730886 -0.98730856
# H -0.0671943 2.0751631 0.7835109
# H 1.0162176 -0.2126565 -0.98064417
# H 0.73995465 -0.08753963 2.0898576
# H 1.3272982 -1.4740405 1.1552814
# H 2.2730422 0.023088757 1.2160546
# H -1.4982442 -0.07637301 0.7967637
# [-1033.67358398 -1033.99829102 -1033.67358398 -1034.22167969
#  -2047.76037598   -17.39214706   -17.3772316    -17.37662506
#    -17.7170372    -17.37658501   -17.3773365    -17.39217186
#    -17.71167946]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7300.479
# hello
# Prediction: -7300.7470703125
# idx 66
# [-1033.54272461]
# number of atoms 11
# C 0.47486082 1.4811767 -0.30994534
# C 0.60074914 -0.014396568 -0.02700048
# O 1.1117369 -0.3123183 1.2625037
# C -0.7467008 -0.722982 -0.108747035
# O -1.5888656 -0.47558346 -0.930893
# H 1.4612727 1.9517622 -0.37279093
# H -0.047447965 1.6337577 -1.2576145
# H -0.094751164 1.9686095 0.48647782
# H 1.2265673 -0.47986794 -0.8108536
# H 1.9857252 0.08151487 1.339327
# H -0.8775402 -1.513038 0.66285294
# [-1033.70861816 -1033.54272461 -2046.53063965 -1034.17114258
#  -2047.96362305   -17.4215641    -17.35296631   -17.35692596
#    -17.71026421   -17.31020927   -17.67798233]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6760.135
# hello
# Prediction: -6759.90380859375
# idx 67
# [-1490.73352051]
# number of atoms 12
# C -0.11099364 1.4434184 0.47809538
# N -0.002798127 -0.002016144 0.43176952
# C 0.040001623 -0.7200755 1.6851245
# C 0.0540585 -0.6464266 -0.76813227
# O 0.023135666 -0.11581948 -1.8586168
# H 0.74327797 1.8817167 1.0089498
# H -0.12971443 1.8105667 -0.5480162
# H -1.0296397 1.7494612 0.99398965
# H -0.86776423 -0.5423311 2.2763772
# H 0.11974856 -1.7927177 1.4909891
# H 0.90314484 -0.4131328 2.290089
# H 0.13439374 -1.7437677 -0.63557583
# [-1033.34777832 -1490.73352051 -1033.2598877  -1034.01525879
#  -2047.85571289   -17.21463203   -17.19655228   -17.21475792
#    -17.19745445   -17.20846939   -17.19734573   -17.4622097 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7300.8467
# hello
# Prediction: -7301.01953125
# idx 68
# [-1034.20202637]
# number of atoms 11
# C 0.018523093 1.929746 0.379988
# C -0.019834245 0.42132896 0.32397303
# O -0.13818796 -0.2750277 1.3099643
# C 0.09629224 -0.24921714 -1.0405195
# O 0.044388887 -1.6388092 -0.9297619
# H 0.95624065 2.3015738 -0.047489148
# H -0.7948941 2.3523576 -0.2200705
# H -0.07350858 2.267425 1.4126698
# H -0.7145395 0.13458408 -1.6828277
# H 1.0387402 0.083044395 -1.5081964
# H -0.05502138 -1.807575 0.021652836
# [-1033.70007324 -1034.20202637 -2048.28564453 -1033.61462402
#  -2046.40063477   -17.44361496   -17.44359398   -17.38998795
#    -17.54846954   -17.54857826   -17.44232559]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6323.3193
# hello
# Prediction: -6323.41064453125
# idx 69
# [-1033.85803223]
# number of atoms 13
# C -0.61982524 1.6664805 -1.0039083
# C -0.5483329 0.14434075 -0.9169824
# C 0.1921622 -0.3629396 0.31523833
# C 0.30251783 -1.8719805 0.45916316
# O 0.6658071 0.391996 1.133117
# H 0.3819803 2.1023846 -1.0329303
# H -1.1604614 1.9790429 -1.9016738
# H -1.1277205 2.0828602 -0.13036482
# H -1.5529125 -0.3016162 -0.9112384
# H -0.057449408 -0.2825825 -1.8028642
# H 0.82326555 -2.3012993 -0.4042383
# H 0.84402764 -2.1190112 1.3729942
# H -0.69349027 -2.328124 0.48664948
# [-1033.6192627  -1033.85803223 -1034.33825684 -1033.68676758
#  -2048.27856445   -17.33752632   -17.36665916   -17.33703613
#    -17.65180588   -17.65163994   -17.44875145   -17.38809967
#    -17.44882202]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6760.627
# hello
# Prediction: -6760.9189453125
# idx 70
# [-1033.82739258]
# number of atoms 12
# C -0.53730226 1.6497821 -1.0462989
# C -0.5674592 0.12840034 -0.9182925
# C 0.16156003 -0.36562595 0.33158806
# N 0.4459392 -1.7040029 0.33315185
# O 0.46882042 0.362401 1.2546724
# H 0.486011 2.0115902 -1.1785219
# H -1.132173 1.978403 -1.9031512
# H -0.9323892 2.1155457 -0.14124314
# H -1.6044617 -0.22919068 -0.85628706
# H -0.1356292 -0.3527295 -1.8044653
# H 0.09771869 -2.3228378 -0.3779473
# H 0.8219793 -2.1058393 1.17634
# [-1033.63293457 -1033.82739258 -1034.02905273 -1489.51513672
#  -2048.23486328   -17.34398651   -17.36009216   -17.31515121
#    -17.63506699   -17.6456604    -17.23408318   -17.14596176]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6760.492
# hello
# Prediction: -6760.55078125
# idx 71
# [-1490.2767334]
# number of atoms 12
# C 0.92028534 1.7583314 -0.14255582
# N 0.84996974 0.31322905 -0.22408625
# C -0.29186803 -0.38296854 0.05755396
# C -0.17574112 -1.8938495 -0.08265948
# O -1.3307432 0.15456864 0.39632693
# H 1.6646259 2.0827246 0.59353846
# H 1.171006 2.202952 -1.1123793
# H -0.06447434 2.1102138 0.1672047
# H 1.6722958 -0.1964372 -0.4982575
# H 0.8149889 -2.2364318 -0.39331728
# H -0.4268908 -2.3549592 0.8761116
# H -0.91494507 -2.23584 -0.811748
# [-1033.20910645 -1490.2767334  -1033.9765625  -1033.67370605
#  -2048.2421875    -17.1893959    -17.18941116   -17.1314621
#    -17.45905876   -17.41136169   -17.39601707   -17.39605141]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7197.5337
# hello
# Prediction: -7197.9091796875
# idx 72
# [-1490.17248535]
# number of atoms 11
# ...
# H 0.34971577 -2.1777477 -0.8166813
# H 0.005656049 -2.1221373 0.93010473
# [-2045.96398926 -1490.22888184 -1033.90063477 -1033.63024902
#  -1489.56152344 -1033.64172363   -17.04804039   -17.45386887
#    -17.40002441   -17.33069611   -17.40511894   -17.47036171]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8771.619
# hello
# Prediction: -8771.9375
# idx 179
# [-1490.27624512]
# number of atoms 11
# O 1.1984096 1.8712116 0.13444936
# N 1.3675387 0.476525 0.110677116
# C 0.2547872 -0.11002844 0.015456532
# C -1.2099502 0.2378442 -0.08095142
# O -1.5282316 -1.1733484 -0.14013264
# C -0.13568805 -1.5650591 -0.05010664
# H 2.1056306 2.1876252 0.20791337
# H -1.64046 0.73513806 0.7975931
# H -1.5122085 0.7809777 -0.9854562
# H 0.20269586 -2.11512 -0.9373104
# H 0.07441963 -2.1611118 0.84698457
# [-2045.9654541  -1490.27624512 -1034.00671387 -1033.63330078
#  -2047.3951416  -1033.6373291    -17.05031967   -17.48798752
#    -17.4879837    -17.49826813   -17.49826622]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -11904.569
# hello
# Prediction: -11904.4853515625
# idx 180
# [-1033.64990234]
# number of atoms 5
# F 0.017971048 -1.321233 -0.0072009326
# C -9.889724e-06 -9.697953e-06 -7.906647e-06
# F 1.2396502 0.45743522 -0.009386671
# F -0.6390913 0.43772456 -1.0706131
# F -0.6185238 0.42607948 1.0872058
# [-2717.70874023 -1033.64990234 -2717.70874023 -2717.70874023
#  -2717.70874023]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8201.663
# hello
# Prediction: -8201.7373046875
# idx 181
# [-1034.55639648]
# number of atoms 10
# O 0.026971139 -1.9862773 -0.011062436
# C 0.010477445 -0.7714962 -0.004195218
# N -1.0874473 0.08225228 0.0145862885
# C -0.69330114 1.4179711 0.016880007
# C 0.6545451 1.4363718 -0.0007875784
# N 1.0848074 0.11190678 -0.013769284
# H -2.0281134 -0.2685841 0.025043013
# H -1.4024192 2.2269795 0.03051134
# H 1.341432 2.264438 -0.0054571824
# H 2.034656 -0.21312271 -0.027630161
# [-2048.01269531 -1034.55639648 -1490.08227539 -1034.0411377
#  -1034.0411377  -1490.08227539   -17.72513962   -17.7359066
#    -17.7359066    -17.72513962]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8742.373
# hello
# Prediction: -8742.4111328125
# idx 182
# [-1034.88232422]
# number of atoms 9
# O 0.032247655 -1.9550726 -0.010785133
# C -0.014862258 -0.75658476 -0.0035465276
# N -1.1027437 0.089899786 0.015412051
# C -0.6822528 1.4191415 0.016699022
# C 0.6548528 1.3847356 -0.0016008457
# O 1.0912724 0.07810784 -0.014445287
# H -2.04667 -0.25240374 0.026267929
# H -1.3677465 2.2483618 0.030251836
# H 1.4090058 2.1511705 -0.007870936
# [-2047.82910156 -1034.88232422 -1490.02111816 -1034.03796387
#  -1034.21386719 -2048.22070312   -17.80191422   -17.72070694
#    -17.68382835]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -9283.045
# hello
# Prediction: -9282.994140625
# idx 183
# [-1035.19030762]
# number of atoms 8
# O 0.026145987 -1.9244626 -0.010387524
# C 0.0100260535 -0.73798144 -0.0040546968
# O -1.1080165 0.0547477 0.015182725
# C -0.68277913 1.3679372 0.016322551
# C 0.6453641 1.386077 -0.001406832
# O 1.1061168 0.08498728 -0.014419764
# H -1.4379857 2.1331844 0.030478606
# H 1.3795052 2.1716628 -0.007133721
# [-2047.57458496 -1035.19030762 -2048.15039062 -1034.27294922
#  -1034.27294922 -2048.15039062   -17.691782     -17.69178009]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6786.448
# hello
# Prediction: -6786.6611328125
# idx 184
# [-1034.69348145]
# number of atoms 13
# C -0.031356744 2.1861475 0.03620802
# C -0.015547663 0.6966281 -0.06881575
# C -0.07218738 -0.13716194 -1.1641673
# C -0.021367583 -1.4819194 -0.69754416
# C 0.06498075 -1.4346031 0.6724033
# N 0.06832139 -0.11087104 1.0423489
# H 0.88168555 2.5809214 0.5001486
# H -0.109746836 2.6266937 -0.9603113
# H -0.8808591 2.5530298 0.62646186
# H -0.14280899 0.18901226 -2.1911163
# H -0.04587775 -2.3773372 -1.2993517
# H 0.12388906 -2.217818 1.4109608
# H 0.123714015 0.2226373 1.9888562
# [-1033.69348145 -1034.69348145 -1034.9473877  -1034.59790039
#  -1034.29418945 -1490.56567383   -17.4341011    -17.42666054
#    -17.43439102   -18.11747742   -18.01259613   -17.7339859
#    -17.70963669]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7327.144
# hello
# Prediction: -7327.19287109375
# idx 185
# [-1034.7989502]
# number of atoms 12
# C 0.021460226 2.1551979 -0.0037196775
# C -0.11351731 0.67500675 -0.02723764
# C -1.1572154 -0.16944866 -0.25049126
# C -0.6402655 -1.5025946 -0.13313983
# C 0.678623 -1.3665541 0.15259406
# O 1.0168914 -0.049302626 0.22088492
# H 0.74130255 2.506341 -0.7518999
# H -0.94471014 2.6181834 -0.21600552
# H 0.3655232 2.513234 0.9733631
# H -2.1724808 0.120988674 -0.4719388
# H -1.1812345 -2.428858 -0.24692592
# H 1.4803436 -2.064213 0.3293561
# [-1033.69787598 -1034.7989502  -1034.95703125 -1034.55126953
#  -1034.49047852 -2048.61962891   -17.42572403   -17.44391441
#    -17.42582893   -18.08057022   -17.99354553   -17.70868492]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7764.1772
# hello
# Prediction: -7764.20654296875
# idx 186
# [-1034.56848145]
# number of atoms 11
# C 0.029975163 2.1685956 0.05332137
# C -0.09854554 0.691882 -0.010295505
# C -1.1038995 -0.17577325 -0.283651
# N -0.6357115 -1.4831933 -0.19258855
# C 0.6072521 -1.3445195 0.12559801
# O 1.0188357 -0.060797848 0.2571499
# H 0.77263343 2.5387166 -0.66209894
# H -0.9311657 2.6314557 -0.18120278
# H 0.3374988 2.5028996 1.0503328
# H -2.1286898 0.04306396 -0.53890187
# H 1.3474296 -2.1101477 0.29718584
# [-1033.69421387 -1034.56848145 -1034.50524902 -1490.91503906
#  -1034.35766602 -2048.52075195   -17.41456223   -17.43300056
#    -17.41463852   -17.77285767   -17.60997772]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7764.229
# hello
# Prediction: -7764.2197265625
# idx 187
# [-1034.5090332]
# number of atoms 11
# C -0.031835586 2.117492 0.03887639
# C -0.02492746 0.6365935 -0.08152519
# N -0.18752609 -0.08959439 -1.1429279
# C -0.08894507 -1.4008038 -0.6898954
# C 0.13155802 -1.3926113 0.6431433
# O 0.17574644 -0.08781286 1.0519907
# H 0.9217353 2.4856942 0.4311521
# H -0.20295203 2.5507996 -0.9466296
# H -0.82041156 2.4541445 0.7197503
# H -0.18428676 -2.2419558 -1.3577474
# H 0.27090243 -2.1412888 1.4034593
# [-1033.63903809 -1034.5090332  -1491.48083496 -1034.1998291
#  -1034.23999023 -2048.53222656   -17.41377068   -17.40162659
#    -17.41374779   -17.70914268   -17.6813736 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7223.034
# hello
# Prediction: -7223.17822265625
# idx 188
# [-1034.16479492]
# number of atoms 12
# N 0.08402913 2.0877652 0.109462984
# C -0.07409626 0.68621844 0.015827008
# C -1.1737548 -0.14291047 -0.03678015
# C -0.69411993 -1.4851516 -0.062116396
# C 0.6783199 -1.4356607 -0.034227833
# N 1.0438446 -0.11067228 0.018622633
# H 0.22458486 2.518753 -0.80054855
# H -0.7417488 2.5101268 0.51656204
# H -2.2034373 0.1803179 -0.068202205
# H -1.2923584 -2.382325 -0.10904028
# H 1.4203851 -2.2171426 -0.04938851
# H 1.9770851 0.2464848 0.12843835
# [-1489.38818359 -1034.16479492 -1034.73840332 -1034.60913086
#  -1034.24462891 -1490.3494873    -17.03723526   -17.04251671
#    -18.12389374   -18.02319717   -17.73940659   -17.71742439]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7763.779
# hello
# Prediction: -7764.14013671875
# idx 189
# [-1034.4909668]
# number of atoms 11
# N 0.039478958 2.040623 0.14023659
# C -0.11326133 0.6659068 0.0141431745
# C -1.1952192 -0.1628858 -0.035361703
# C -0.6576558 -1.4963948 -0.065214425
# C 0.689669 -1.3754 -0.037406992
# O 1.0385346 -0.044451427 0.014336804
# H 0.8810183 2.3794427 -0.30915445
# H -0.76837325 2.5521553 -0.18679585
# H -2.2324347 0.13023244 -0.048473265
# H -1.2155704 -2.4189932 -0.107551664
# H 1.5130893 -2.0679257 -0.04864662
# [-1489.44140625 -1034.4909668  -1034.73901367 -1034.54455566
#  -1034.36938477 -2048.49438477   -17.11832619   -17.15561676
#    -18.10514259   -17.99605751   -17.68580627]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8200.791
# hello
# Prediction: -8201.1513671875
# idx 190
# [-1034.19946289]
# number of atoms 10
# N 0.05751744 2.0515969 0.15321425
# C -0.09625418 0.683091 0.014456444
# C -1.1502949 -0.17351104 -0.059256192
# N -0.6620201 -1.4795315 -0.083657034
# C 0.61625963 -1.3508785 -0.032588076
# O 1.0482568 -0.052819323 0.03354846
# H 0.8683747 2.4117582 -0.3344171
# H -0.7734853 2.564676 -0.10646645
# H -2.2044003 0.046225417 -0.09556422
# H 1.381946 -2.1089962 -0.0404614
# [-1489.42895508 -1034.19946289 -1034.28723145 -1490.93945312
#  -1034.24780273 -2048.40258789   -17.11711121   -17.17777443
#    -17.77085876   -17.58023262]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8200.998
# hello
# Prediction: -8201.119140625
# idx 191
# [-1034.25610352]
# number of atoms 10
# N 0.010812962 1.9914123 0.12757173
# C -0.08749826 0.6272216 0.014523515
# N -1.1644077 -0.09604534 -0.022384208
# C -0.67665493 -1.4025596 -0.053517636
# C 0.6709739 -1.3893281 -0.04181607
# O 1.0728699 -0.06473925 0.0044582123
# H 0.8391265 2.3917592 -0.2879153
# H -0.8406551 2.4664807 -0.13269572
# H -1.3420392 -2.2507162 -0.08652704
# H 1.4554061 -2.1242244 -0.062383097
# [-1489.43115234 -1034.25610352 -1491.29272461 -1034.11914062
#  -1034.10595703 -2048.36669922   -17.08742332   -17.10353851
#    -17.70127487   -17.65508652]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7763.958
# hello
# Prediction: -7764.2353515625
# idx 192
# [-1034.52380371]
# number of atoms 11
# O 0.061939266 2.01119 0.15818825
# C 0.023991097 0.66960704 -0.055151127
# C 0.032197233 -0.110921085 -1.1860048
# C -0.026842333 -1.4688886 -0.7372645
# C -0.06766629 -1.4617902 0.63164276
# N -0.03596691 -0.13942534 1.0408688
# H 0.105373755 2.44923 -0.6967428
# H 0.07467515 0.24122977 -2.2050233
# H -0.03728232 -2.346621 -1.3648454
# H -0.1159724 -2.2607381 1.3522879
# H -0.053493273 0.19657177 1.9875808
# [-2046.71508789 -1034.52380371 -1034.7434082  -1034.56689453
#  -1034.29736328 -1490.31335449   -17.33237839   -18.21405602
#    -18.00032234   -17.7279892    -17.80038643]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8200.913
# hello
# Prediction: -8200.9951171875
# idx 193
# [-1034.25317383]
# number of atoms 10
# O 0.066783965 2.0219512 0.17118156
# C 0.02565166 0.6847658 -0.040752783
# C 0.029953439 -0.1297183 -1.1422192
# N -0.029245589 -1.4519935 -0.740978
# C -0.068189576 -1.4292912 0.56492805
# N -0.036791116 -0.14315265 1.0492679
# H 0.10977956 2.4644787 -0.68199426
# H 0.071487166 0.15039533 -2.1835127
# H -0.118645705 -2.2850466 1.2205378
# H -0.055030238 0.16080332 2.008436
# [-2046.70581055 -1034.25317383 -1034.26000977 -1490.98205566
#  -1034.07910156 -1490.18005371   -17.34444046   -17.84647369
#    -17.52831841   -17.81627083]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -8201.218
# hello
# Prediction: -8201.2314453125
# idx 194
# [-1034.3638916]
# number of atoms 10
# O 0.058543723 1.9666169 0.12128715
# C 0.021730486 0.63049096 -0.023694528
# N 0.0526069 -0.04004116 -1.1429306
# C -0.0092226975 -1.3694682 -0.7508722
# C -0.07701095 -1.4752977 0.6062665
# N -0.05585943 -0.1635582 1.072876
# H 0.11252036 2.3302002 -0.77143896
# H -0.00070819986 -2.1646636 -1.479806
# H -0.1362156 -2.314835 1.2773875
# H -0.091008514 0.14886867 2.0276623
# [-2046.68969727 -1034.3638916  -1491.31591797 -1034.18713379
#  -1034.07067871 -1490.08654785   -17.28187943   -17.68574524
#    -17.72819901   -17.8226223 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -6786.3926
# hello
# Prediction: -6786.5908203125
# idx 195
# [-1035.26574707]
# number of atoms 13
# C -0.031088967 2.2300835 0.012675522
# C -0.009759761 0.7307335 0.010967884
# C -0.070950046 -0.08790182 -1.0946803
# N -0.024082145 -1.3931975 -0.6684928
# C 0.066523544 -1.4275553 0.69881576
# C 0.07756921 -0.12878036 1.148457
# H 0.8753708 2.65004 0.46467212
# H -0.10382606 2.6249728 -1.0051252
# H -0.8819796 2.6249046 0.58051044
# H -0.14354451 0.15358627 -2.1435575
# H -0.052457593 -2.1984632 -1.2676991
# H 0.11500821 -2.3646114 1.2300478
# H 0.14126565 0.18127781 2.1810424
# [-1033.71838379 -1035.26574707 -1034.6003418  -1490.25695801
#  -1034.30871582 -1034.94250488   -17.42711449   -17.43023491
#    -17.42711639   -17.78650665   -17.61695099   -17.73088837
#    -18.07888412]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7223.4644
# hello
# Prediction: -7223.57275390625
# idx 196
# [-1034.64697266]
# number of atoms 12
# C -0.031199092 2.1878486 0.045192145
# C -0.0158449 0.6950732 -0.021126237
# C -0.18457025 -0.11515559 -1.1148723
# N -0.08232359 -1.4069208 -0.6408166
# C 0.1405552 -1.3227085 0.6997748
# N 0.18660384 -0.0763758 1.106796
# H 0.9190312 2.5750115 0.42852172
# H -0.20418054 2.6244526 -0.9423175
# H -0.81767875 2.5442312 0.71914196
# H -0.36247593 0.09692864 -2.1561222
# H -0.15855965 -2.2491233 -1.1851631
# H 0.2598325 -2.198695 1.3201709
# [-1033.67626953 -1034.64697266 -1034.37072754 -1490.16418457
#  -1034.08044434 -1491.45080566   -17.41479111   -17.41334343
#    -17.41479301   -17.79986191   -17.61011696   -17.53057098]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7327.032
# hello
# Prediction: -7326.96826171875
# idx 197
# [-1035.22644043]
# number of atoms 12
# C -0.027199136 2.239844 0.0146357985
# C -0.00827548 0.74280417 0.015654532
# C -0.07246413 -0.08567235 -1.0610979
# O -0.03019966 -1.3923581 -0.68022114
# C 0.06450644 -1.3985627 0.67439437
# C 0.08239744 -0.1304284 1.1569532
# H 0.8834374 2.6535544 0.4626185
# H -0.105474725 2.6331666 -1.0027238
# H -0.87422305 2.6314316 0.5893411
# H -0.1484509 0.09096435 -2.121668
# H 0.108720414 -2.3712125 1.1360075
# H 0.15102462 0.16117409 2.1939368
# [-1033.69946289 -1035.22644043 -1034.6739502  -2048.19311523
#  -1034.49475098 -1034.890625     -17.43903732   -17.44142723
#    -17.43899536   -17.72284126   -17.70241547   -18.04533577]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7764.1357
# hello
# Prediction: -7764.138671875
# idx 198
# [-1034.62719727]
# number of atoms 11
# C -0.025557686 2.1989844 0.050718155
# C -0.011328827 0.70974475 -0.019979056
# C -0.09148077 -0.1113606 -1.095163
# O -0.03667423 -1.408261 -0.65693265
# C 0.07565565 -1.2948114 0.68378633
# N 0.09673148 -0.081908815 1.1260012
# H 0.8928239 2.5760527 0.51258695
# H -0.11598697 2.639367 -0.945492
# H -0.8629319 2.55222 0.6614229
# H -0.1836644 0.032826908 -2.1577091
# H 0.13578399 -2.2143064 1.2448684
# [-1033.65234375 -1034.62719727 -1034.45495605 -2048.09912109
#  -1034.37756348 -1491.34790039   -17.42617226   -17.42393494
#    -17.42618179   -17.69749832   -17.6062088 ]
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask']
# Truth: -7222.95
# hello
# Prediction: -7223.359375
# idx 199
# [-1034.6809082]
# number of atoms 12
# N -0.005692062 2.1282692 0.14363734
# C -0.007854533 0.72284895 0.019614803
# C -1.1067057 -0.10989778 -0.014792392
# N -0.6420837 -1.4106531 -0.051510666
# C 0.7224995 -1.415036 -0.049859595
# C 1.1512624 -0.10719989 -0.0033716182
# H 0.7572223 2.5502377 -0.37142733
# H -0.87242293 2.541682 -0.17710328
# H -2.1619174 0.10952999 -0.0074467207
# H -1.2246798 -2.2269578 -0.08720497
# H 1.2789508 -2.3378847 -0.0814753
# H 2.1778305 0.22626103 0.021304151
# [-1489.39221191 -1034.6809082  -1034.4230957  -1490.29321289
#  -1034.25231934 -1034.75268555   -17.11026001   -17.13426018
#    -17.81874847   -17.61245918   -17.74265099   -18.14589691]

# %%
# Take the average AE for each atom (for "1-atom only" PCA) and write to excel sheet

    numH = 0
    numC = 0
    numN = 0
    numO = 0
    numF = 0
    h=0
    c=0
    n=0
    o=0
    f=0
    for i in range(len(z)):
        atomicnumbers = props['_atomic_numbers'][i]
        if atomicnumbers == 1:
            numH = numH + atomenergies[0,i]
            h = h +1
        if atomicnumbers == 6:
            numC = numC + atomenergies[0,i]
            c = c +1
        if atomicnumbers == 7:
            numN = numN + atomenergies[0,i]
            n = n+1
        if atomicnumbers == 8:
            numO = numO + atomenergies[0,i]
            o = o + 1
        if atomicnumbers == 9:
            numF = numF + atomenergies[0,i]
            f = f + 1
    if numH != 0:
        aveH = numH[0]/h
    else:
        aveH = 0
    if numC != 0:
        aveC = numC[0]/c
    else:
        aveC = 0
    if numN != 0:
        aveN = numN[0]/n
    else:
        aveN = 0
    if numO != 0:
        aveO = numO[0]/o
    else:
        aveO = 0
    if numF !=0:
        aveF = numF[0]/f
    else:
        aveF = 0
    print(aveC)
    print(aveH)
    print(aveN)
    print(aveO)
    print(aveF)

# Write the target properties to an excel file for PCA analysis
