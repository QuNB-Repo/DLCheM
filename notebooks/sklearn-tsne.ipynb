# %%
import numpy as np
import pandas as pd

import sklearn
from sklearn.manifold import TSNE

from sklearn.datasets import load_digits

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

import seaborn as sb

# %%
x = pd.read_csv("../data/data/qm9_i6_30f/50epochs/50000-test-points/data.csv") 

#Implementing the TSNE Function - ah Scikit learn makes it so easy!
digits_final = TSNE(perplexity=300).fit_transform(x) 
#Play around with varying the parameters like perplexity, random_state to get different plots

print(digits_final)
# Out:
# [[-26.894253 -32.92941 ]
#  [-19.556995 -33.011642]
#  [-37.46654   22.221315]
#  ...
#  [ 16.249569 -26.726479]
#  [ 16.61727  -27.627144]
#  [ -7.646555  18.570795]]

# %%
label=pd.read_csv("../data/data/qm9_i6_30f/50epochs/50000-test-points/label-o.csv")
colors=['maroon','gold','skyblue','purple','lightcoral','forestgreen','black','chocolate','grey','red']
def plot(x):

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 6))
    ax = plt.subplot(aspect='equal')
    plt.xlabel('tSNE-1')
    plt.ylabel('tSNE-2')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,c=label['Target'],cmap=matplotlib.colors.ListedColormap(colors))

plot(digits_final)
