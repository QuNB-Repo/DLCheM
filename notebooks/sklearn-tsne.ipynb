# %%
import numpy as np
import pandas as pd

import sklearn
from sklearn.manifold import TSNE

from sklearn.datasets import load_digits

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

import seaborn as sb

# %%
x = pd.read_csv("../data/data/qm9_i6_30f/50epochs/3000-test-points/rep-o.csv") 

#Implementing the TSNE Function - ah Scikit learn makes it so easy!
digits_final = TSNE(perplexity=30).fit_transform(x) 
#Play around with varying the parameters like perplexity, random_state to get different plots

print(digits_final)
# Out:
# [[-49.716366    49.73196   ]
#  [ 47.963085    -2.2928877 ]
#  [-18.37843     42.038124  ]
#  ...
#  [ 76.65301      5.4202757 ]
#  [-16.83328      0.90275145]
#  [  7.423077   -15.704099  ]]

# %%
label=pd.read_csv("../data/data/qm9_i6_30f/50epochs/3000-test-points/label-o.csv")
colors=['maroon','gold','skyblue','purple','lightcoral','forestgreen','black','chocolate','grey','red','blue']
def plot(x):

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 6))
    ax = plt.subplot(aspect='equal')
    plt.xlabel('tSNE-1')
    plt.ylabel('tSNE-2')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40,c=label['Target'],cmap=matplotlib.colors.ListedColormap(colors))

plot(digits_final)
