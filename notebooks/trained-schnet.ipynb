# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
from numpy import genfromtxt, savetxt
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

calculator = spk.interfaces.SpkCalculator(model=model, device=device, energy=QM9.U0)
converter = spk.data.AtomsConverter(device=device)
# load data for molecule
at, props = qm9data.get_properties(13)

# set calculator on molecule
at.set_calculator(calculator)

# convert qm9 data to machine-readable form
inputs = converter(at)


pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])
print('Keys:', list(inputs.keys()))
print('Truth:', props[QM9.U0].cpu().numpy()[0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


x = x.detach().numpy()
print(x[0][8])
z = np.zeros(30)
for i in range(30):
    z[i] = x[0][8][i]
# Out:
# Prediction: -4217.3306
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask', 'representation']
# Truth: -4217.023
# tensor([[[-1033.5311],
#          [-1033.5496],
#          [-2046.5616],
#          [  -17.3803],
#          [  -17.3803],
#          [  -17.3479],
#          [  -17.3185],
#          [  -17.3185],
#          [  -16.9430]]], grad_fn=<AddBackward0>)
# [ 0.873716    0.72314894  2.2314045  -1.055411    1.7409477   1.6494476
#   2.4670506   5.095903    0.14799182 -7.002657    1.331481   -1.3886635
#   0.16347688  1.3694193  -3.5233307  -2.7108958   1.5107887   0.5807687
#  -0.0275597   2.9418695  -0.08728649  1.9064639  -0.9612253  -2.9872088
#   1.1584371   1.1594511   3.0716043   0.03464839 -1.2672491  -0.67741585]

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis2.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)

x = x.detach().numpy()
print(x[0][8])
z = np.zeros(30)
for i in range(30):
    z[i] = x[0][8][i]

print(z)
# Out:
# Prediction: -4218.53
# tensor([[[-1033.5732],
#          [-1033.5774],
#          [-2047.0161],
#          [  -17.4733],
#          [  -17.3658],
#          [  -17.3889],
#          [  -17.3889],
#          [  -17.3728],
#          [  -17.3728]]], grad_fn=<AddBackward0>)
# [-0.51658505  1.8643203   0.71664757  0.33644342  2.7771304  -0.43251517
#   1.260131    2.0335727   0.99730337 -4.217264   -0.29221678 -1.1096499
#  -1.1510872  -1.4722742   0.8835117  -2.3961847   0.08462888  0.49352393
#   0.37247065 -0.43126577  0.28620416  0.05957144  0.9291179   0.1323758
#   1.1483123  -1.3055406  -0.7718257  -0.4072759   0.31449732 -1.0546603 ]
# [-0.51658505  1.86432028  0.71664757  0.33644342  2.77713037 -0.43251517
#   1.260131    2.03357267  0.99730337 -4.21726418 -0.29221678 -1.1096499
#  -1.15108716 -1.47227418  0.88351172 -2.39618468  0.08462888  0.49352393
#   0.37247065 -0.43126577  0.28620416  0.05957144  0.92911792  0.13237581
#   1.14831233 -1.30554056 -0.77182567 -0.40727589  0.31449732 -1.05466032]

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis3.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


x = x.detach().numpy()
print(x[0][8])
z = np.zeros(30)
for i in range(30):
    z[i] = x[0][8][i]
    
print(z)
# Out:
# Prediction: -4218.53
# tensor([[[-1033.5732],
#          [-1033.5774],
#          [-2047.0161],
#          [  -17.4733],
#          [  -17.3658],
#          [  -17.3889],
#          [  -17.3889],
#          [  -17.3728],
#          [  -17.3728]]], grad_fn=<AddBackward0>)
# [-0.51658505  1.8643203   0.71664757  0.33644342  2.7771304  -0.43251517
#   1.260131    2.0335727   0.99730337 -4.217264   -0.29221678 -1.1096499
#  -1.1510872  -1.4722742   0.8835117  -2.3961847   0.08462888  0.49352393
#   0.37247065 -0.43126577  0.28620416  0.05957144  0.9291179   0.1323758
#   1.1483123  -1.3055406  -0.7718257  -0.4072759   0.31449732 -1.0546603 ]
# [-0.51658505  1.86432028  0.71664757  0.33644342  2.77713037 -0.43251517
#   1.260131    2.03357267  0.99730337 -4.21726418 -0.29221678 -1.1096499
#  -1.15108716 -1.47227418  0.88351172 -2.39618468  0.08462888  0.49352393
#   0.37247065 -0.43126577  0.28620416  0.05957144  0.92911792  0.13237581
#   1.14831233 -1.30554056 -0.77182567 -0.40727589  0.31449732 -1.05466032]

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis4.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


print(x)
# Out:
# Prediction: -4218.53
# tensor([[[-1033.5732],
#          [-1033.5774],
#          [-2047.0161],
#          [  -17.4733],
#          [  -17.3658],
#          [  -17.3889],
#          [  -17.3889],
#          [  -17.3728],
#          [  -17.3728]]], grad_fn=<AddBackward0>)
# tensor([[[-1.3468,  1.0117,  0.6345, -0.0378,  2.9618, -1.5334, -0.9348,
#            4.1826,  1.4608, -4.7305,  0.8645, -1.7537, -1.5458, -0.1885,
#           -2.6309, -2.6601, -0.6184,  0.3064, -1.4664,  0.6776,  0.0819,
#            0.8442, -0.5064, -2.5298, -0.7821,  0.9581, -2.2033, -1.5046,
#           -0.2412, -2.7409],
#          [-0.5243,  2.5019,  0.4180, -0.4041,  2.2111, -1.2708,  0.0385,
#            2.8952, -0.3822, -5.6090,  0.9585, -1.7383, -2.9014, -0.8800,
#           -2.1035, -2.8596,  2.5515,  0.0191, -1.0353,  2.0375,  1.3390,
#            1.3576, -0.4864,  0.3206, -0.1298,  0.2384, -1.8484, -0.6027,
#           -1.0986, -2.0047],
#          [ 1.3959, -0.8670,  0.1407,  0.6849,  0.0681, -0.3361,  1.1854,
#           -2.4867, -2.6070, -0.2047, -0.3030,  0.6356,  0.1994, -1.3002,
#            0.4858, -2.2078,  0.6411, -0.9393,  1.0491, -0.4907,  0.2496,
#            0.2191, -0.3149, -1.1019,  0.2436,  1.6973, -0.0060, -1.3776,
#           -0.9727, -0.6970],
#          [-0.9071,  0.2106,  1.3699,  0.0544,  1.6087,  0.6606,  0.9568,
#            3.0557, -0.4966, -1.7893,  0.3373, -0.4180, -0.2675, -0.0225,
#            0.2079, -0.7022, -0.9229, -0.8080,  0.6438,  1.2426,  1.3144,
#           -0.2561, -0.7975, -0.2783,  0.5427,  0.0697,  0.1990, -0.9140,
#            0.3221, -0.8207],
#          [-1.6933,  2.0669,  0.6593,  0.2459,  3.5843,  0.7699,  0.0631,
#            1.7374,  0.8197, -3.9198,  0.4997, -1.5765,  0.5137,  0.0891,
#            0.7661, -1.4800, -1.3445,  0.5964,  0.8291,  1.1622,  0.5046,
#            1.2377, -0.4082, -0.5322, -0.5054, -0.2271,  0.6301, -0.4299,
#            0.4039, -1.2482],
#          [-1.1319,  2.1733,  0.3327,  0.8146,  3.2840,  0.7249, -0.1037,
#            2.1140,  1.1133, -3.7002, -0.7099, -1.8232, -0.1501, -0.5264,
#            0.5892, -1.3191, -1.1022,  0.3729,  0.7128,  0.3068,  0.8388,
#            0.5170, -0.0159, -0.1870,  0.8388,  0.5274,  0.0156, -0.5023,
#            0.5670, -0.9983],
#          [-1.1319,  2.1733,  0.3327,  0.8146,  3.2840,  0.7249, -0.1037,
#            2.1140,  1.1133, -3.7002, -0.7099, -1.8232, -0.1501, -0.5264,
#            0.5892, -1.3191, -1.1022,  0.3729,  0.7128,  0.3068,  0.8388,
#            0.5170, -0.0159, -0.1870,  0.8388,  0.5274,  0.0156, -0.5023,
#            0.5670, -0.9983],
#          [-0.5166,  1.8643,  0.7166,  0.3364,  2.7771, -0.4325,  1.2601,
#            2.0336,  0.9973, -4.2173, -0.2922, -1.1096, -1.1511, -1.4723,
#            0.8835, -2.3962,  0.0846,  0.4935,  0.3725, -0.4313,  0.2862,
#            0.0596,  0.9291,  0.1324,  1.1483, -1.3055, -0.7718, -0.4073,
#            0.3145, -1.0547],
#          [-0.5166,  1.8643,  0.7166,  0.3364,  2.7771, -0.4325,  1.2601,
#            2.0336,  0.9973, -4.2173, -0.2922, -1.1096, -1.1511, -1.4723,
#            0.8835, -2.3962,  0.0846,  0.4935,  0.3725, -0.4313,  0.2862,
#            0.0596,  0.9291,  0.1324,  1.1483, -1.3055, -0.7718, -0.4073,
#            0.3145, -1.0547]]], grad_fn=<AddBackward0>)

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis5.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


print(x)

# %%
from schnetpack.datasets import QM9
        
at, props = qm9data.get_properties(13)    

# convert qm9 data to machine-readable form
inputs = converter(at)

calculator = spk.interfaces.SpkCalculator(model=model, device=device, energy=QM9.U0)
at.set_calculator(calculator)

pred = model(inputs)
from schnetpack.representation.schnet import x0
from schnetpack.atomistic.output_modules import yi

from schnetpack.representation.schnet import v

print(yi)
print(v)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])
# Out:
# tensor([[[-1033.5311],
#          [-1033.5496],
#          [-2046.5616],
#          [  -17.3803],
#          [  -17.3803],
#          [  -17.3479],
#          [  -17.3185],
#          [  -17.3185],
#          [  -16.9430]]], grad_fn=<AddBackward0>)
# tensor([[[-2.0070e-02, -1.2018e-01, -4.8509e-01, -3.3334e-01, -3.2861e-01,
#            2.4058e-01, -5.4608e-01, -4.3546e-02,  3.6813e-01, -5.6585e-01,
#            2.1026e-01, -8.2096e-01, -4.2437e-01, -3.1172e-01,  1.2935e-01,
#            9.8918e-03, -4.4588e-01, -6.6941e-04, -2.1074e-01, -1.8167e-01,
#            5.7560e-01, -3.8204e-01, -3.9405e-01, -4.4155e-01,  1.1846e-01,
#            3.0199e-01, -4.7728e-01,  1.0010e-01, -8.9314e-02, -2.0802e-01],
#          [ 3.3703e-01, -1.0521e+00, -1.3421e+00, -1.7541e-01, -1.3550e-01,
#            3.0121e-02, -8.1325e-01, -7.9196e-01,  4.2789e-01,  1.6062e-02,
#            1.1511e+00, -1.3611e+00, -5.3497e-01,  1.3626e-01,  6.5030e-01,
#            3.2648e-01,  1.1300e+00, -8.6349e-01,  9.0586e-01, -8.3910e-01,
#           -1.1475e-01, -1.2023e+00,  3.5227e-01, -1.2278e+00,  1.6278e+00,
#            2.3836e-01, -4.5472e-01, -1.1082e+00,  5.8062e-01,  2.7858e-01],
#          [-8.5585e-01,  1.1775e+00, -1.0028e+00,  2.2840e-01,  4.4389e-01,
#           -1.7211e-01, -1.2848e+00, -5.2433e-01, -1.5681e-01, -4.1297e-01,
#           -1.9910e-01, -1.7196e+00,  1.8156e-01, -1.8711e-01,  1.0770e-01,
#           -6.7592e-01, -4.4151e-01, -2.5513e-01,  3.1176e-01, -2.4926e-01,
#            2.1895e-01,  7.5375e-01,  3.3936e-01,  9.4309e-01, -1.7503e-01,
#           -6.2015e-01, -6.2244e-01, -3.0537e-01,  8.4780e-01, -1.1045e+00],
#          [-8.1437e-01,  1.0422e+00, -5.2057e-01,  3.0375e-01,  3.3219e-01,
#            2.0072e-01, -1.1023e+00, -1.0521e-01, -4.5700e-01, -6.6546e-01,
#           -1.5521e-01, -1.4141e+00,  1.2820e-01,  8.0673e-02,  3.2027e-01,
#            1.1934e-01, -5.9562e-01, -2.4109e-01,  6.0049e-01,  8.4143e-01,
#            3.7755e-01,  4.0267e-01, -3.2377e-01,  1.2197e-01,  2.7737e-01,
#            3.2363e-01, -1.1100e-01,  3.1154e-01,  4.0380e-01, -8.9424e-01],
#          [-8.1435e-01,  1.0422e+00, -5.2063e-01,  3.0373e-01,  3.3227e-01,
#            2.0075e-01, -1.1023e+00, -1.0518e-01, -4.5701e-01, -6.6545e-01,
#           -1.5532e-01, -1.4142e+00,  1.2829e-01,  8.0718e-02,  3.2014e-01,
#            1.1931e-01, -5.9569e-01, -2.4105e-01,  6.0049e-01,  8.4140e-01,
#            3.7750e-01,  4.0284e-01, -3.2370e-01,  1.2200e-01,  2.7716e-01,
#            3.2356e-01, -1.1102e-01,  3.1151e-01,  4.0385e-01, -8.9442e-01],
#          [-4.5242e-01,  9.9197e-01, -5.8601e-01,  2.2821e-02,  4.4401e-01,
#            5.1872e-01, -9.5721e-01, -2.6408e-02, -3.1757e-01, -8.5646e-01,
#           -3.7916e-01, -1.1881e+00,  2.3569e-01,  2.5936e-01, -5.5879e-03,
#            2.9430e-02, -6.3118e-01, -3.8630e-02,  5.5596e-01,  8.6028e-01,
#            2.5451e-01,  3.2458e-01, -2.6871e-01, -4.9478e-02, -1.0494e-01,
#            2.8760e-01, -7.8577e-03,  2.2749e-01,  2.1494e-01, -7.3261e-01],
#          [-6.1141e-01,  1.1549e+00, -2.8999e-01, -1.0750e-01,  5.7421e-01,
#           -3.7109e-01,  6.3191e-01,  1.2381e-01, -1.3335e-01, -5.3209e-02,
#            4.8906e-01, -2.7117e-01, -2.3565e-01,  3.8265e-01,  1.7857e-03,
#           -9.5434e-01, -7.1069e-03, -6.2918e-01,  5.2968e-01,  6.5240e-01,
#           -1.3059e-01, -9.0859e-02,  2.1956e-01,  8.2035e-02,  8.9432e-01,
#            4.7649e-01,  3.3989e-01,  8.3917e-01,  6.7127e-02,  2.6144e-01],
#          [-6.1138e-01,  1.1546e+00, -2.9012e-01, -1.0735e-01,  5.7408e-01,
#           -3.7096e-01,  6.3144e-01,  1.2389e-01, -1.3325e-01, -5.3184e-02,
#            4.8907e-01, -2.7126e-01, -2.3560e-01,  3.8247e-01,  2.0047e-03,
#           -9.5405e-01, -6.9505e-03, -6.2925e-01,  5.2979e-01,  6.5222e-01,
#           -1.3051e-01, -9.0740e-02,  2.1951e-01,  8.1830e-02,  8.9460e-01,
#            4.7665e-01,  3.3981e-01,  8.3900e-01,  6.7113e-02,  2.6127e-01],
#          [ 8.5148e-01, -4.7117e-01, -8.7419e-02, -5.4521e-01, -5.8477e-01,
#            4.5558e-01,  4.3194e-01, -2.7902e-01,  6.6871e-02, -1.1762e+00,
#            2.8371e-01, -2.6845e-01, -5.6869e-01, -3.5043e-02, -4.4324e-01,
#            5.5938e-01, -1.0232e-01,  4.8010e-01,  5.6434e-01,  2.5797e-01,
#            2.4839e-01, -4.3679e-01, -3.2633e-01, -3.4806e-01,  3.4655e-01,
#            9.3793e-02,  4.5979e-01,  3.6099e-01, -4.8641e-01,  1.3295e+00]]],
#        grad_fn=<AddBackward0>)
# Prediction: -4217.3306
