# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
from numpy import genfromtxt, savetxt
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

calculator = spk.interfaces.SpkCalculator(model=model, device=device, energy=QM9.U0)
converter = spk.data.AtomsConverter(device=device)
# load data for molecule
at, props = qm9data.get_properties(13)

# set calculator on molecule
at.set_calculator(calculator)

# convert qm9 data to machine-readable form
inputs = converter(at)


pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])
print('Keys:', list(inputs.keys()))
print('Truth:', props[QM9.U0].cpu().numpy()[0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x


print(x0)
# Out:
# Prediction: -4217.3306
# Keys: ['_atomic_numbers', '_positions', '_cell', '_neighbors', '_cell_offset', '_atom_mask', '_neighbor_mask', 'representation']
# Truth: -4217.023
# tensor([[[ 2.0301,  1.0917, -0.5336,  1.6991, -2.4143, -0.4750, -0.6691,
#           -0.4063,  0.4054, -0.9130,  0.1568,  1.4542,  0.7196, -0.2830,
#            0.3571,  0.6797,  0.6272,  0.9105, -1.3556, -0.6457, -0.5105,
#            1.1326,  1.0114,  0.9688, -0.2629, -0.1348,  0.8805,  2.2940,
#            0.0168, -0.3046],
#          [ 2.0301,  1.0917, -0.5336,  1.6991, -2.4143, -0.4750, -0.6691,
#           -0.4063,  0.4054, -0.9130,  0.1568,  1.4542,  0.7196, -0.2830,
#            0.3571,  0.6797,  0.6272,  0.9105, -1.3556, -0.6457, -0.5105,
#            1.1326,  1.0114,  0.9688, -0.2629, -0.1348,  0.8805,  2.2940,
#            0.0168, -0.3046],
#          [ 2.5857, -0.8526,  0.6067,  0.5333,  0.3904, -0.2492, -0.0512,
#           -2.1845, -3.2352,  0.2497, -1.1760,  2.1401,  0.7494,  0.3333,
#            2.5486, -0.5589,  1.8157, -1.5638,  1.2403,  0.1952,  0.6629,
#            0.2311, -0.4256, -0.4230, -0.5898,  0.4304,  1.0051, -0.6147,
#           -0.6907, -0.0259],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797],
#          [-0.5116,  0.2157,  1.6834,  0.1183,  1.0574,  0.5305,  1.4205,
#            3.1107, -0.4970, -1.5248,  0.2906,  0.7268,  0.3487,  0.5113,
#            0.5021, -0.6532, -0.6986, -0.9714,  0.1471,  1.2982,  1.5445,
#           -0.4106, -0.7916,  0.1958,  0.0569, -0.4838,  1.1272, -0.0835,
#            0.5079, -0.9797]]], grad_fn=<CloneBackward>)

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis2.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)

x = x.detach().numpy()
print(x[0][8])
z = np.zeros(30)
for i in range(30):
    z[i] = x[0][8][i]

print(z)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-877643551129> in <module>
#      23 device = 'cpu'
#      24
# ---> 25 atoms = read('../../../data/single-shot/etoh-dis2.xyz')
#      26
#      27 converter = spk.data.AtomsConverter(device=device)
#
# ~\Anaconda3\lib\site-packages\ase\io\formats.py in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     673     if index is None:
#     674         index = -1
# --> 675     format = format or filetype(filename, read=isinstance(filename, str))
#     676
#     677     io = get_ioformat(format)
#
# ~\Anaconda3\lib\site-packages\ase\io\formats.py in filetype(filename, read, guess)
#     856
#     857         if orig_filename == filename:
# --> 858             fd = open_with_compression(filename, 'rb')
#     859         else:
#     860             fd = orig_filename # type: ignore
#
# ~\Anaconda3\lib\site-packages\ase\io\formats.py in open_with_compression(filename, mode)
#     495     else:
#     496         # Either None or unknown string
# --> 497         return open(filename, mode)
#     498
#     499
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../data/single-shot/etoh-dis2.xyz'

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis3.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


x = x.detach().numpy()
print(x[0][8])
z = np.zeros(30)
for i in range(30):
    z[i] = x[0][8][i]
    
print(z)

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis4.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


print(x)

# %%
### #Loads the best_model after schnet training.
#user evaluates the model on the QM9 database

import schnetpack as spk
import torch
import schnetpack.nn 
import schnetpack.data
from schnetpack.datasets import QM9

from ase.io import read
import numpy as np
# Load best model where it was stored after training

model = torch.load("../../../data/trained_models/qm9_i6_30f_10000_5000/best_model", map_location=torch.device('cpu'))

# Download QM9 dataset to use in evaluating model
qm9data = QM9('./qm9.db', download=True, remove_uncharacterized=True)

# Load split file 
train, val, test = spk.data.train_test_split(qm9data, split_file='../../../data/trained_models/qm9_i6_30f_10000_5000/split.npz')


device = 'cpu'

atoms = read('../../../data/single-shot/etoh-dis5.xyz')

converter = spk.data.AtomsConverter(device=device)
inputs = converter(atoms)

pred = model(inputs)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])

from schnetpack.atomistic.output_modules import yi
from schnetpack.atomistic.output_modules import y0
from schnetpack.representation.schnet import x0
from schnetpack.representation.schnet import x

print(yi)


print(x)

# %%
from schnetpack.datasets import QM9
        
at, props = qm9data.get_properties(13)    

# convert qm9 data to machine-readable form
inputs = converter(at)

calculator = spk.interfaces.SpkCalculator(model=model, device=device, energy=QM9.U0)
at.set_calculator(calculator)

pred = model(inputs)
from schnetpack.representation.schnet import x0
from schnetpack.atomistic.output_modules import yi

from schnetpack.representation.schnet import v

print(yi)
print(v)

print('Prediction:', pred[QM9.U0].detach().cpu().numpy()[0,0])
